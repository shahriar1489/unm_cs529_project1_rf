# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 


import sys

# Arithmetic 
import math
from fractions import Fraction
from decimal import Decimal

# %%
import numpy as np

# Example column vector
column_vector = np.array([1, 2, 3, 2, 2, 4, 5, 2, 66, 66, 66, 66, 66])

# Find the index of the maximum occurring value
max_index = np.argmax(np.bincount(column_vector))


# Get the maximum occurring value
max_value = np.bincount(column_vector).argmax()

print("Maximum occurring index:", max_index)
print("Maximum occurring value:", max_value)
# Out:
# Maximum occurring index: 66
# Maximum occurring value: 66

# %%
np.argmax(np.bincount(column_vector))
# Out:
# 66

# %%
"""
import numpy as np

# Create a NumPy array representing the column vector
data = np.array([222,222,222,222,222,222,222,222, 1, 1, 0, 1, 1, 0, 0, 1])

# Find the most frequent target value
target_value, target_count = np.unique(data, return_counts=True)
most_frequent_value = target_value[np.argmax(target_count)]






print("The most frequent value is:", most_frequent_value)
"""
# Out:
# '\nimport numpy as np\n\n# Create a NumPy array representing the column vector\ndata = np.array([222,222,222,222,222,222,222,222, 1, 1, 0, 1, 1, 0, 0, 1])\n\n# Find the most frequent target value\ntarget_value, target_count = np.unique(data, return_counts=True)\nmost_frequent_value = target_value[np.argmax(target_count)]\n\n\n\n\n\n\nprint("The most frequent value is:", most_frequent_value)\n'

# %%
#label_value

# %%
#label_count

# %%
#np.argmax(label_count) # return index number

# %%
import numpy as np

arr = np.array([[1, 2, 3], 
                [4, 5, 6]])

for row in arr:
    for element in row:
        print(element)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
for i in np.array([2, 4, 6, 8]): 
    print(i)
# Out:
# 2
# 4
# 6
# 8

# %%
def compute_impurity_by_label(attribute, impurity='gini'): # Impurity of the total dataset : DONE
        
        """
        FEATURES: 
        
        attribute : pandas df
            the column whose entropy is to be calculated
        
        impurity : string 
            the impurity measure used- gini or entropty 
        
        
        Returns 
            np real scalar number 
        """
        
        print("--> In method: compute_impurity_by_label ")
        # get the total number of instances/rows in the dataset
        N = attribute.shape[0]
        
        print('\t\t Number of rows in attribute param:', N)
        #sys.exit(0)
    
        # get the count
        label_values, label_counts = np.unique(attribute, return_counts=True)
        label_fractions = []
    
    
        # get the fractions for the each of the labels- better to use loop be cause there can be more than two labels
    
        for count in label_counts :
            print(Decimal(count/N)) 
            
            result_float = float( count/ Decimal(N) )
            
            label_fractions.append( result_float  )
    
    
        print('\t\tlabel_fractions: ',label_fractions)
        
        label_fractions = np.array( label_fractions )
        print('\t\tDifferent label values collected: ', label_values)
        print('\t\tDifferent label counts colleceted: ', label_counts)
        print('\t\tFractions of different labels: ', label_fractions)
    
    
        # write a subroutine for entropy
        if impurity=='entropy':
            #return  - np.sum ( label_fractions * np.log2(  label_fractions ) ) # This returns the complete entropy 
            print('-------------\n\n\n')
            #print("\t\t\tInside impurity=entropy",  -1 * label_fractions * np.log2(label_fractions) ) 
    
            print("-------------\t\t\entropy = ", -np.sum(  label_fractions * np.log2(label_fractions) ) )
            
            
            return -np.sum(  label_fractions * np.log2(label_fractions) )
            
            
            
            
    
        # write a subroutine for gini
        elif impurity=='gini':  
    
          return 1 - np.sum(  np.square( label_fractions )   ) # 1 - sum of elementwise fraction #This returns the complete gini
    
    
        # write the third metric 
    
    
    
        else :
          print("ERROR: impurity metric can be either of gini or entropy.")
          return -1

# %%
# Define the discrete values
discrete_values = ['A', 'B']

# Generate the test data
test_data = pd.DataFrame({'attribute': np.random.choice(discrete_values, size=100)})

print(test_data.head())
# Out:
#   attribute
# 0         A
# 1         B
# 2         B
# 3         A
# 4         A

# %%
test_data.shape
# Out:
# (100, 1)

# %%
test_data.columns
# Out:
# Index(['attribute'], dtype='object')

# %%
compute_impurity_by_label(test_data, impurity='gini')
# Out:
# --> In method: compute_impurity_by_label
# 		 Number of rows in attribute param: 100
# 0.5100000000000000088817841970012523233890533447265625
# 0.4899999999999999911182158029987476766109466552734375
# 		label_fractions:  [0.51, 0.49]
# 		Different label values collected:  ['A' 'B']
# 		Different label counts colleceted:  [51 49]
# 		Fractions of different labels:  [0.51 0.49]
# 0.4998

# %%
compute_impurity_by_label(test_data, impurity='entropy')
# Out:
# --> In method: compute_impurity_by_label
# 		 Number of rows in attribute param: 100
# 0.5100000000000000088817841970012523233890533447265625
# 0.4899999999999999911182158029987476766109466552734375
# 		label_fractions:  [0.51, 0.49]
# 		Different label values collected:  ['A' 'B']
# 		Different label counts colleceted:  [51 49]
# 		Fractions of different labels:  [0.51 0.49]
# -------------
#
#
#
# -------------		\entropy =  0.9997114417528099
# 0.9997114417528099

# %%
"""
Issues reported in the compute_impurity_by_label method: 

    i) entropy is returning more than 1 
        
        - Proposed solution: 
            - Use a 



"""


# Define the labels and their counts
labels = ['A'] * 60 + ['B'] * 10 

# Shuffle the labels to randomize the order
np.random.shuffle(labels)

# Create a DataFrame with the labels
test_data_2 = pd.DataFrame({'attribute': labels})

#print(test_data_2.head())


print( 'entropy:\t',compute_impurity_by_label(test_data_2, impurity='entropy') ) 
#|print( 'gini:\t', compute_impurity_by_label(test_data_2, impurity='gini') )
# Out:
# --> In method: compute_impurity_by_label
# 		 Number of rows in attribute param: 70
# 0.85714285714285709527615608749329112470149993896484375
# 0.142857142857142849212692681248881854116916656494140625
# 		label_fractions:  [0.8571428571428571, 0.14285714285714285]
# 		Different label values collected:  ['A' 'B']
# 		Different label counts colleceted:  [60 10]
# 		Fractions of different labels:  [0.85714286 0.14285714]
# -------------
#
#
#
# -------------		\entropy =  0.5916727785823275
# entropy:	 0.5916727785823275

# %%
type( Decimal(60/100) )
# Out:
# decimal.Decimal

# %%
float( Decimal(60/100) )
# Out:
# 0.6

# %%
-0.73697 * -.6
# Out:
# 0.442182

# %%
import numpy as np

# Given label counts
label_counts = np.array([60,  30])

# Total count of labels
total_count = np.sum(label_counts)

# Calculate probabilities
probabilities = label_counts / total_count

# Calculate entropy
entropy = -np.sum(probabilities * np.log2(probabilities))

print("Entropy:", entropy)
# Out:
# Entropy: 0.9182958340544896

# %%
test_data_1 = pd.read_csv('test_data_1.csv')

test_data_1.head()
# Out:
#   ProductCD       card4   card6  isFraud
# 0         C  mastercard   debit        0
# 1         W        visa   debit        0
# 2         H        visa   debit        0
# 3         W    discover  credit        0
# 4         W        visa   debit        0

# %%
test_data_1['ProductCD']
# Out:
# 0         C
# 1         W
# 2         H
# 3         W
# 4         W
#          ..
# 472427    W
# 472428    W
# 472429    W
# 472430    W
# 472431    H
# Name: ProductCD, Length: 472432, dtype: object

# %%
def information_gain_for_discrete_attribute(examples_a, target_attribute, impurity='entropy'): # 02/28/2024 This stays. Fix this 
        """

        Parameters
        ----------
        examples_a : the attribute column whose feature is to be calculated 
            type: Pandas Series 
            
        target_attribute : attribute whose value is to be predicted by tree 
            type: Pandas Series  
        
        attribute : attribute/column name for examples_a
            type: string
        
        impurity_measure : gini/entropy 
            type: string

        Returns
        -------
        scalar real number  
            
        
        
        self.information_gain( examples[a], target_attribute, 'entropy') # examples is pd df

        """
        
        #impurity_for_target_attribute = self.compute_impurity_for_discrete_attribute(target_attribute, impurity=impurity)
        
        
        # get the unique values in examples_a
        examples_a_values = np.unique(examples_a)
        
        N = examples_a.shape[0]
        
        result = compute_impurity_by_label(  np.array( target_attribute ), impurity=impurity)
        
        print( '\t\t\tresult after initialization : ', result) # ok 
        
        #sys.exit(0)
        for a in examples_a_values: 
            
            # get the subset of examples_a and corresponding tuple in target_attribute
            #examples_a[attribute]
            #print( examples_a[examples_a==a])
            #print('-----')
            #print('feature subset shape:\n', examples_a[examples_a==a].shape)
            #print('-----')
            
            #print( 'target subset shape:\n', target_attribute[examples_a==a].shape )
        
            
            #examples_a_subset = np.array( examples_a[examples_a==a] ) 
            """
            I don't need the line above rn
            """
            
            
            #target_a_subset = np.array( target_attribute[examples_a==a] ) # converting to np for faster computation
            
            n = target_attribute[examples_a==a].shape[0]
            #compute_impurity_by_label(  np.array( target_attribute[examples_a==a] ), impurity=impurity)
            
            
            prob_float = float( n/ Decimal(N) )
            
            result = result - ( prob_float *  compute_impurity_by_label(  np.array( target_attribute[examples_a==a] ), impurity=impurity) ) 
                    
            
            print('\t\t---------------\t\t\n')
            #sys.exit(0)
            
            
            
            print('\t\t\t--- final info gain : ', result )
        return result # returns a scalar real number

# %%
information_gain_for_discrete_attribute( test_data_1['ProductCD'], test_data_1['isFraud'], impurity='entropy')
# Out:
# --> In method: compute_impurity_by_label
# 		 Number of rows in attribute param: 472432
# 0.9650108375385240133681463703396730124950408935546875
# 0.034989162461475938059596302309728343971073627471923828125
# 		label_fractions:  [0.965010837538524, 0.03498916246147594]
# 		Different label values collected:  [0 1]
# 		Different label counts colleceted:  [455902  16530]
# 		Fractions of different labels:  [0.96501084 0.03498916]
# -------------
#
#
#
# -------------		\entropy =  0.21882586530176718
# 			result after initialization :  0.21882586530176718
# --> In method: compute_impurity_by_label
# 		 Number of rows in attribute param: 54643
# 0.88269311714217735254095487107406370341777801513671875
# 0.117306882857822591947893897668109275400638580322265625
# 		label_fractions:  [0.8826931171421774, 0.11730688285782259]
# 		Different label values collected:  [0 1]
# 		Different label counts colleceted:  [48233  6410]
# 		Fractions of different labels:  [0.88269312 0.11730688]
# -------------
#
#
#
# -------------		\entropy =  0.521569715414749
# 		---------------
#
# 			--- final info gain :  0.15849943957402618
# --> In method: compute_impurity_by_label
# 		 Number of rows in attribute param: 26489
# 0.9523575823926913042072328607900999486446380615234375
# 0.0476424176073086957927671392099000513553619384765625
# 		label_fractions:  [0.9523575823926913, 0.047642417607308696]
# 		Different label values collected:  [0 1]
# 		Different label counts colleceted:  [25227  1262]
# 		Fractions of different labels:  [0.95235758 0.04764242]
# -------------
#
#
#
# -------------		\entropy =  0.2762964223711254
# 		---------------
#
# 			--- final info gain :  0.1430076525397255
# --> In method: compute_impurity_by_label
# 		 Number of rows in attribute param: 30111
# 0.96197402942446286200350868966779671609401702880859375
# 0.03802597057553717962985473377557354979217052459716796875
# 		label_fractions:  [0.9619740294244629, 0.03802597057553718]
# 		Different label values collected:  [0 1]
# 		Different label counts colleceted:  [28966  1145]
# 		Fractions of different labels:  [0.96197403 0.03802597]
# -------------
#
#
#
# -------------		\entropy =  0.23316695318724723
# 		---------------
#
# 			--- final info gain :  0.1281464870652843
# --> In method: compute_impurity_by_label
# 		 Number of rows in attribute param: 9328
# 0.9433962264150943521912040523602627217769622802734375
# 0.05660377358490566168658375545419403351843357086181640625
# 		label_fractions:  [0.9433962264150944, 0.05660377358490566]
# 		Different label values collected:  [0 1]
# 		Different label counts colleceted:  [8800  528]
# 		Fractions of different labels:  [0.94339623 0.05660377]
# -------------
#
#
#
# -------------		\entropy =  0.3138129641688651
# 		---------------
#
# 			--- final info gain :  0.121950362903993
# --> In method: compute_impurity_by_label
# 		 Number of rows in attribute param: 351861
# 0.97958000460409078158363627153448760509490966796875
# 0.0204199953959091802524472569757563178427517414093017578125
# 		label_fractions:  [0.9795800046040908, 0.02041999539590918]
# 		Different label values collected:  [0 1]
# 		Different label counts colleceted:  [344676   7185]
# 		Fractions of different labels:  [0.97958 0.02042]
# -------------
#
#
#
# -------------		\entropy =  0.1437922468945473
# 		---------------
#
# 			--- final info gain :  0.014855831236869885
# 0.014855831236869885

# %%
np.unique( test_data_1['ProductCD'], return_counts = True)
# Out:
# (array(['C', 'H', 'R', 'S', 'W'], dtype=object),
#  array([ 54643,  26489,  30111,   9328, 351861]))

# %%
test_data_1['ProductCD'].shape[0]
# Out:
# 472432

# %%
information_gain_for_discrete_attribute( test_data_1['card4'], test_data_1['isFraud'], impurity='entropy')
# Out:
# --> In method: compute_impurity_by_label
# 		 Number of rows in attribute param: 472432
# 0.9650108375385240133681463703396730124950408935546875
# 0.034989162461475938059596302309728343971073627471923828125
# 		label_fractions:  [0.965010837538524, 0.03498916246147594]
# 		Different label values collected:  [0 1]
# 		Different label counts colleceted:  [455902  16530]
# 		Fractions of different labels:  [0.96501084 0.03498916]
# -------------
#
#
#
# -------------		\entropy =  0.21882586530176718
# 			result after initialization :  0.21882586530176718
# --> In method: compute_impurity_by_label
# 		 Number of rows in attribute param: 1269
# 0.97241922773837663473983639050857163965702056884765625
# 0.0275807722616233270962471380016722832806408405303955078125
# 		label_fractions:  [0.9724192277383766, 0.027580772261623327]
# 		Different label values collected:  [0 1]
# 		Different label counts colleceted:  [1234   35]
# 		Fractions of different labels:  [0.97241923 0.02758077]
# -------------
#
#
#
# -------------		\entropy =  0.18211053219929707
# 		---------------
#
# 			--- final info gain :  0.21833669804518652
# --> In method: compute_impurity_by_label
# 		 Number of rows in attribute param: 6638
# 0.9713769207592648502469501181622035801410675048828125
# 0.0286230792407351601613907376986389863304793834686279296875
# 		label_fractions:  [0.9713769207592649, 0.02862307924073516]
# 		Different label values collected:  [0 1]
# 		Different label counts colleceted:  [6448  190]
# 		Fractions of different labels:  [0.97137692 0.02862308]
# -------------
#
#
#
# -------------		\entropy =  0.18743895843937042
# 		---------------
#
# 			--- final info gain :  0.21570304959182066
# --> In method: compute_impurity_by_label
# 		 Number of rows in attribute param: 5350
# 0.9224299065420560328476540234987623989582061767578125
# 0.07757009345794392551898255305786733515560626983642578125
# 		label_fractions:  [0.922429906542056, 0.07757009345794393]
# 		Different label values collected:  [0 1]
# 		Different label counts colleceted:  [4935  415]
# 		Fractions of different labels:  [0.92242991 0.07757009]
# -------------
#
#
#
# -------------		\entropy =  0.39355885167144466
# 		---------------
#
# 			--- final info gain :  0.21124623918007415
# --> In method: compute_impurity_by_label
# 		 Number of rows in attribute param: 151030
# 0.96580811759253126780322418198920786380767822265625
# 0.034191882407468711380094106289107003249228000640869140625
# 		label_fractions:  [0.9658081175925313, 0.03419188240746871]
# 		Different label values collected:  [0 1]
# 		Different label counts colleceted:  [145866   5164]
# 		Fractions of different labels:  [0.96580812 0.03419188]
# -------------
#
#
#
# -------------		\entropy =  0.21499674911056593
# 		---------------
#
# 			--- final info gain :  0.1425147412752566
# --> In method: compute_impurity_by_label
# 		 Number of rows in attribute param: 308145
# 0.9651917116941699514853780783596448600292205810546875
# 0.0348082883058300485146219216403551399707794189453125
# 		label_fractions:  [0.96519171169417, 0.03480828830583005]
# 		Different label values collected:  [0 1]
# 		Different label counts colleceted:  [297419  10726]
# 		Fractions of different labels:  [0.96519171 0.03480829]
# -------------
#
#
#
# -------------		\entropy =  0.21795958016275585
# 		---------------
#
# 			--- final info gain :  0.0003500385683010976
# 0.0003500385683010976

# %%
np.unique( test_data_1['isFraud'], return_counts=True)
# Out:
# (array([0, 1]), array([455902,  16530]))

# %%
test_data_1['isFraud'].shape[0]
# Out:
# 472432

# %%
"""

"""

df_cont_1 = pd.read_csv('train.csv')
print( df_cont_1.columns ) 

df_cont_1 = df_cont_1[['TransactionAmt', 'isFraud']]
# Out:
# Index(['TransactionID', 'ProductCD', 'card1', 'card2', 'card3', 'card4',
#        'card5', 'card6', 'addr1', 'addr2', 'TransactionDT', 'TransactionAmt',
#        'C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9', 'C10', 'C11',
#        'C12', 'C13', 'C14', 'isFraud'],
#       dtype='object')

# %%
df_cont_1

examples_a = df_cont_1['TransactionAmt']
target_attribute = df_cont_1['isFraud']

# %%
# sample 

def sample_continuous_attribute(examples_a,  target_attribute,  sampling_threshold=0.2): 
    """
    Parameters: 
    
    - examples_a : pandas series 
    
    - target_attribute : pandas series 
    
    
    Notice that column name is passed with pd series 
    
    Returns: 
    - pandas df with the resampled df of shape (n, 2)
    
    """
    
    
    
    attribute = examples_a.name
    target = target_attribute.name
    
    print('\tattribute and target name : ', attribute, ', ', target)
    
    
    
    df = pd.concat([examples_a, target_attribute], axis=1)
    #df.rename(columns[])
    print('Columns of new df formed', df.columns)
    
    
    """
    I have a pseudocode for stratified sampling at this point
    """
    
    df_0 = df[ df[target] == 0 ]
    df_1 = df[ df[target] == 1 ]
    
    
    """
    I am keeping all the 1 and then taking only a 
    """
    
    print('df_0.shape ', df_0.shape)
    
    print('-----')
    print("Different quartile values for the continuous variable ", attribute, '\n')
    
    low = df_0[attribute].quantile(0.00)
    print('\t\tlow: ', low)
    
    first_quartile = df_0[attribute].quantile(0.25)
    print('\t\tfirst quartile: ', first_quartile)
    
    median = df_0[attribute].quantile(0.50)
    print('\t\tmedian: ', median)
    
    third_quartile = df_0[attribute].quantile(0.75) 
    print('\t\tthird_quartile: ', third_quartile)
    
    high = df_0[attribute].quantile(1.00)
    print('\t\thigh: ', high)
    
    
    # Filter tuples in df_0 below the first quartile
    df_25 = df_0[   df_0[attribute ] < df_0[attribute].quantile(0.25)    ]
    
    
    df_50 = df_0[ (df_0[attribute].quantile(0.25) <= df_0[attribute]) & ( df_0[attribute] < df_0[attribute].quantile(0.50) )]
    

    
    df_75 = df_0[ (df_0[attribute].quantile(0.50) <= df_0[attribute])  & ( df_0[attribute] < df_0[attribute].quantile(0.75) )]
    
    df_100 =  df_0[( df_0[attribute].quantile(0.75) <= df_0[attribute] )]    #(df_0[attribute].quantile(0.75) <= df_0[df[attribute] ) 

    
    print('1st df_0, ', df_25.shape)
    print('2nd df_0, ', df_50.shape)
    print('3rd df_0, ', df_75.shape)
    print('4th df_0, ', df_100.shape)
    #print(df_below_first_quartile.shape)
    
    
    """
    
    Take a samples of each interval 
    
    
    """

    
    
    SAMPLE_SIZE_0 = math.ceil(df_1.shape[0] * 4) 
    
    quartile_sample_size = math.floor( SAMPLE_SIZE_0 / 4 ) 
    
    
    
    print('df_1.shape : ', df_1.shape[0] ) 
    print('SAMPLE_SIZE_0', SAMPLE_SIZE_0)    
    print('quartile_sample_size', quartile_sample_size)    
    
    
    # Got all the info to .sample rn
    
    
    df_25_sampled = df_25.sample(n = quartile_sample_size)
    df_50_sampled = df_50.sample(n = quartile_sample_size)
    df_75_sampled = df_75.sample(n = quartile_sample_size)
    df_100_sampled = df_100.sample(n =quartile_sample_size)
    
    
    print(df_25_sampled.shape)
    print(df_50_sampled.shape)
    print(df_75_sampled.shape)
    print(df_100_sampled.shape)
    
    #print(df_0_25_sample_size)
    
    #df_0_50_sample_size = 
    #df_0_75_sample_size = 
    #df_0_100_sample_size = df.
    
    
    df_sampled = pd.concat([df_25_sampled, df_50_sampled, df_75_sampled, df_100_sampled, df_1], axis=0) 
    
    
    print('In original dataset:', np.unique(target_attribute, return_counts=True))
    #print('In sampled dataset: ', np.unique(df_sampled['isFraud'], return_counts=True)) 
    
    """
    - At this point, I have got the stratified sampled data that I want 
    - 
    
    """
    
    print('In new, sampled dataset', df_sampled.shape)
    
    #return df_sampled.sample(frac=1).reset_index(drop=True) 
    
    
    df_sampled = df_sampled.sample(frac=1, random_state=1)
    
    examples_a_sampled = df_sampled.iloc[:, 0]
    target_a_sampled = df_sampled.iloc[:, -1]
    
    
    return examples_a_sampled, target_a_sampled

# %%
examples_a_sampled, target_a_sampled = sample_continuous_attribute(examples_a, target_attribute, sampling_threshold=0.2)
# Out:
# 	attribute and target name :  TransactionAmt ,  isFraud
# Columns of new df formed Index(['TransactionAmt', 'isFraud'], dtype='object')
# df_0.shape  (455902, 2)
# -----
# Different quartile values for the continuous variable  TransactionAmt
#
# 		low:  0.251
# 		first quartile:  43.97
# 		median:  68.5
# 		third_quartile:  120.0
# 		high:  31940.0
# 1st df_0,  (113819, 2)
# 2nd df_0,  (113898, 2)
# 3rd df_0,  (114198, 2)
# 4th df_0,  (113987, 2)
# df_1.shape :  16530
# SAMPLE_SIZE_0 66120
# quartile_sample_size 16530
# (16530, 2)
# (16530, 2)
# (16530, 2)
# (16530, 2)
# In original dataset: (array([0, 1]), array([455902,  16530]))
# In new, sampled dataset (82650, 2)

# %%
16530 * 3, 16530 * 4
# Out:
# (49590, 66120)

# %%
113819+ 113898 + 114198 + 113987
# Out:
# 455902

# %%
16530*4
# Out:
# 66120

# %%
display(target_a_sampled.tail())
display(np.unique(target_a_sampled, return_counts=True))
# Out:
# 309113    0
# 206968    1
# 206625    0
# 270576    0
# 333127    1
# Name: isFraud, dtype: int64
# (array([0, 1]), array([66120, 16530]))

# %%
def information_gain_for_continuous_attribute( examples_a, target_attribute, impurity='entropy'): # 02/28/2024 This stays. Fix this 
        """
        Parameters
        ----------
        examples_a : The attribute column whose feature is to be calculated. The name is passed 
            type: Pandas Series 
            
        target_attribute : Attribute whose value is to be predicted by tree. The name is passed 
            type: Pandas Series  
        
        
        impurity_measure : gini/entropy 
            type: string

        Returns
        -------
        scalar real number  
            
        
        
        self.information_gain( examples[a], target_attribute, 'entropy') # examples is pd df

        """
        print("\t\t--> In method: information_gain_for_continuous_attribute ")
        
        df_cont = pd.concat([ examples_a, target_attribute ], axis=1)
        attr = examples_a.name
        targ = target_attribute.name
        impurity_parent_node = compute_impurity_by_label(target_attribute, impurity=impurity)
        N = examples_a.shape[0]
        
        
        
        #sys.exit(0)
        print('number of attribute instances in parent node: ', N)
        print('impurity_parent_node : ', impurity_parent_node)
        
        
        print('Feature/attribute name: ', attr)
        
        
        highest_info_gain = float('-inf')
        p_ = None # the percentile w/ highest info gain 
        #perc_value 
        # The percentles where we are splitting- 
        percentiles = [ 0.25, 0.375, .50, 0.625, 0.75]
        
        #sys.exit(0)
        for p in percentiles: 
            print('------')
            print(p)
            percentile_value = examples_a.quantile(p)
            print('percentile_value : ', percentile_value)
            
        
            # get the dataset above and below this percentile 
            df_below = df_cont[ df_cont[attr] < percentile_value ]
            df_above = df_cont[ df_cont[attr] >= percentile_value]
            
            print('percentile value : ', p)
            print('df_below.shape : ', df_below.shape)
            print('df_above.shape : ', df_above.shape)
            
            print('labels below percentile: ', np.unique( df_below[targ], return_counts=True ))  
            print('labels above percentile: ', np.unique( df_above[targ], return_counts=True )) 
            
            
            impurity_below = compute_impurity_by_label(df_below[targ], impurity=impurity)
            impurity_above = compute_impurity_by_label(df_above[targ], impurity=impurity)
            
            
            print('impurity_below : ',impurity_below )
            print('impurity above : ', impurity_above )
            
            n_below = df_below.shape[0]
            n_above = df_above.shape[0]
            
            print('n_below : ', n_below)
            print('n_above : ', n_above)
            
            info_gain = impurity_parent_node - float( (n_below/N) * impurity_below  ) - float( (n_above/N) * impurity_above  )
            
            
            if info_gain > highest_info_gain:
                highest_info_gain = info_gain 
                p_ = p 
                #perc_value = 
            
            print("info_gain :", info_gain)
            
            print('=====')
            
            
            
            """
            - Notice that the featue column rn holds the "technically" the same value in either below and above 
            - Use the info gain by label 
            """
        print('Interval w/ highest info gain ' , p_) 
            
            
            
            
            
            #sys.exit(0)

# %%
50+12.5
# Out:
# 62.5

# %%
information_gain_for_continuous_attribute( examples_a_sampled, target_a_sampled, impurity='entropy')
# Out:
# 		--> In method: information_gain_for_continuous_attribute
# --> In method: compute_impurity_by_label
# 		 Number of rows in attribute param: 82650
# 0.8000000000000000444089209850062616169452667236328125
# 0.200000000000000011102230246251565404236316680908203125
# 		label_fractions:  [0.8, 0.2]
# 		Different label values collected:  [0 1]
# 		Different label counts colleceted:  [66120 16530]
# 		Fractions of different labels:  [0.8 0.2]
# -------------
#
#
#
# -------------		\entropy =  0.7219280948873623
# number of attribute instances in parent node:  82650
# impurity_parent_node :  0.7219280948873623
# Feature/attribute name:  TransactionAmt
# ------
# 0.25
# percentile_value :  40.12
# percentile value :  0.25
# df_below.shape :  (20656, 2)
# df_above.shape :  (61994, 2)
# labels below percentile:  (array([0, 1]), array([15850,  4806]))
# labels above percentile:  (array([0, 1]), array([50270, 11724]))
# --> In method: compute_impurity_by_label
# 		 Number of rows in attribute param: 20656
# 0.76733152594887688024982708157040178775787353515625
# 0.2326684740511231475057485340585117228329181671142578125
# 		label_fractions:  [0.7673315259488769, 0.23266847405112315]
# 		Different label values collected:  [0 1]
# 		Different label counts colleceted:  [15850  4806]
# 		Fractions of different labels:  [0.76733153 0.23266847]
# -------------
#
#
#
# -------------		\entropy =  0.7826341276648044
# --> In method: compute_impurity_by_label
# 		 Number of rows in attribute param: 61994
# 0.81088492434751746618104562003281898796558380126953125
# 0.1891150756524825060633787643382675014436244964599609375
# 		label_fractions:  [0.8108849243475175, 0.1891150756524825]
# 		Different label values collected:  [0 1]
# 		Different label counts colleceted:  [50270 11724]
# 		Fractions of different labels:  [0.81088492 0.18911508]
# -------------
#
#
#
# -------------		\entropy =  0.6996165919265495
# impurity_below :  0.7826341276648044
# impurity above :  0.6996165919265495
# n_below :  20656
# n_above :  61994
# info_gain : 0.0015636479310560114
# =====
# ------
# 0.375
# percentile_value :  55.135
# percentile value :  0.375
# df_below.shape :  (30994, 2)
# df_above.shape :  (51656, 2)
# labels below percentile:  (array([0, 1]), array([24380,  6614]))
# labels above percentile:  (array([0, 1]), array([41740,  9916]))
# --> In method: compute_impurity_by_label
# 		 Number of rows in attribute param: 30994
# 0.786603858811382838922554583405144512653350830078125
# 0.213396141188617161077445416594855487346649169921875
# 		label_fractions:  [0.7866038588113828, 0.21339614118861716]
# 		Different label values collected:  [0 1]
# 		Different label counts colleceted:  [24380  6614]
# 		Fractions of different labels:  [0.78660386 0.21339614]
# -------------
#
#
#
# -------------		\entropy =  0.7479243861486562
# --> In method: compute_impurity_by_label
# 		 Number of rows in attribute param: 51656
# 0.80803778844664708724820911811548285186290740966796875
# 0.1919622115533529405073664975134306587278842926025390625
# 		label_fractions:  [0.8080377884466471, 0.19196221155335294]
# 		Different label values collected:  [0 1]
# 		Different label counts colleceted:  [41740  9916]
# 		Fractions of different labels:  [0.80803779 0.19196221]
# -------------
#
#
#
# -------------		\entropy =  0.7055582549615751
# impurity_below :  0.7479243861486562
# impurity above :  0.7055582549615751
# n_below :  30994
# n_above :  51656
# info_gain : 0.0004824125814146818
# =====
# ------
# 0.5
# percentile_value :  69.85
# percentile value :  0.5
# df_below.shape :  (41325, 2)
# df_above.shape :  (41325, 2)
# labels below percentile:  (array([0, 1]), array([33320,  8005]))
# labels above percentile:  (array([0, 1]), array([32800,  8525]))
# --> In method: compute_impurity_by_label
# 		 Number of rows in attribute param: 41325
# 0.8062915910465819901986606055288575589656829833984375
# 0.1937084089534180375569150101000559516251087188720703125
# 		label_fractions:  [0.806291591046582, 0.19370840895341804]
# 		Different label values collected:  [0 1]
# 		Different label counts colleceted:  [33320  8005]
# 		Fractions of different labels:  [0.80629159 0.19370841]
# -------------
#
#
#
# -------------		\entropy =  0.7091650230067135
# --> In method: compute_impurity_by_label
# 		 Number of rows in attribute param: 41325
# 0.79370840895341798759687890196801163256168365478515625
# 0.2062915910465819846475454824030748568475246429443359375
# 		label_fractions:  [0.793708408953418, 0.20629159104658198]
# 		Different label values collected:  [0 1]
# 		Different label counts colleceted:  [32800  8525]
# 		Fractions of different labels:  [0.79370841 0.20629159]
# -------------
#
#
#
# -------------		\entropy =  0.7343341951022542
# impurity_below :  0.7091650230067135
# impurity above :  0.7343341951022542
# n_below :  41325
# n_above :  41325
# info_gain : 0.0001784858328784944
# =====
# ------
# 0.625
# percentile_value :  103.94
# percentile value :  0.625
# df_below.shape :  (51629, 2)
# df_above.shape :  (31021, 2)
# labels below percentile:  (array([0, 1]), array([41462, 10167]))
# labels above percentile:  (array([0, 1]), array([24658,  6363]))
# --> In method: compute_impurity_by_label
# 		 Number of rows in attribute param: 51629
# 0.8030757907377636950485566558199934661388397216796875
# 0.1969242092622363327070189598089200444519519805908203125
# 		label_fractions:  [0.8030757907377637, 0.19692420926223633]
# 		Different label values collected:  [0 1]
# 		Different label counts colleceted:  [41462 10167]
# 		Fractions of different labels:  [0.80307579 0.19692421]
# -------------
#
#
#
# -------------		\entropy =  0.7157336961727556
# --> In method: compute_impurity_by_label
# 		 Number of rows in attribute param: 31021
# 0.79488088714096905018635652595548890531063079833984375
# 0.2051191128590309775692190896734246052801609039306640625
# 		label_fractions:  [0.794880887140969, 0.20511911285903098]
# 		Different label values collected:  [0 1]
# 		Different label counts colleceted:  [24658  6363]
# 		Fractions of different labels:  [0.79488089 0.20511911]
# -------------
#
#
#
# -------------		\entropy =  0.7320489216485814
# impurity_below :  0.7157336961727556
# impurity above :  0.7320489216485814
# n_below :  51629
# n_above :  31021
# info_gain : 7.080997309927284e-05
# =====
# ------
# 0.75
# percentile_value :  135.5
# percentile value :  0.75
# df_below.shape :  (61984, 2)
# df_above.shape :  (20666, 2)
# labels below percentile:  (array([0, 1]), array([50516, 11468]))
# labels above percentile:  (array([0, 1]), array([15604,  5062]))
# --> In method: compute_impurity_by_label
# 		 Number of rows in attribute param: 61984
# 0.81498451213216316357801360936718992888927459716796875
# 0.1850154878678368641775620062617235817015171051025390625
# 		label_fractions:  [0.8149845121321632, 0.18501548786783686]
# 		Different label values collected:  [0 1]
# 		Different label counts colleceted:  [50516 11468]
# 		Fractions of different labels:  [0.81498451 0.18501549]
# -------------
#
#
#
# -------------		\entropy =  0.6909270030926371
# --> In method: compute_impurity_by_label
# 		 Number of rows in attribute param: 20666
# 0.75505661472950735824127832529484294354915618896484375
# 0.244943385270492586247570443447330035269260406494140625
# 		label_fractions:  [0.7550566147295074, 0.2449433852704926]
# 		Different label values collected:  [0 1]
# 		Different label counts colleceted:  [15604  5062]
# 		Fractions of different labels:  [0.75505661 0.24494339]
# -------------
#
#
#
# -------------		\entropy =  0.8031647622286839
# impurity_below :  0.6909270030926371
# impurity above :  0.8031647622286839
# n_below :  61984
# n_above :  20666
# info_gain : 0.002936899050556524
# =====
# Interval w/ highest info gain  0.75

# %%
#def cont_info_gain(nv, df) output:

# %%
examples_a.shape[0]
# Out:
# 472432

# %%
tree = [['apple', 'banana', 'orange'],
        ['grape', 'kiwi', 'pear'],
        ['pineapple', 'melon', 'strawberry']]

# %%
# Initialize a list to store the indices of sublists where test_attribute is present
#indices = [index for index, sublist in enumerate(tree) if test_attribute in sublist]

#print("Indices of sublists where 'banana' is present:", indices)

# %%
df_tennis = pd.read_csv('PlayTennis.csv')

display(df_tennis)
print('---------------------------------')
df_tennis['windy'] = df_tennis['windy'].astype(str)
display(df_tennis.dtypes)
# Out:
#      outlook  temp humidity  windy play
# 0      sunny   hot     high  False   no
# 1      sunny   hot     high   True   no
# 2   overcast   hot     high  False  yes
# 3      rainy  mild     high  False  yes
# 4      rainy  cool   normal  False  yes
# 5      rainy  cool   normal   True   no
# 6   overcast  cool   normal   True  yes
# 7      sunny  mild     high  False   no
# 8      sunny  cool   normal  False  yes
# 9      rainy  mild   normal  False  yes
# 10     sunny  mild   normal   True  yes
# 11  overcast  mild     high   True  yes
# 12  overcast   hot   normal  False  yes
# 13     rainy  mild     high   True   no
# ---------------------------------
# outlook     object
# temp        object
# humidity    object
# windy       object
# play        object
# dtype: object

# %%
for _, row in df_tennis.iterrows(): 
    print(_)
    print(row)
# Out:
# 0
# outlook     sunny
# temp          hot
# humidity     high
# windy       False
# play           no
# Name: 0, dtype: object
# 1
# outlook     sunny
# temp          hot
# humidity     high
# windy        True
# play           no
# Name: 1, dtype: object
# 2
# outlook     overcast
# temp             hot
# humidity        high
# windy          False
# play             yes
# Name: 2, dtype: object
# 3
# outlook     rainy
# temp         mild
# humidity     high
# windy       False
# play          yes
# Name: 3, dtype: object
# 4
# outlook      rainy
# temp          cool
# humidity    normal
# windy        False
# play           yes
# Name: 4, dtype: object
# 5
# outlook      rainy
# temp          cool
# humidity    normal
# windy         True
# play            no
# Name: 5, dtype: object
# 6
# outlook     overcast
# temp            cool
# humidity      normal
# windy           True
# play             yes
# Name: 6, dtype: object
# 7
# outlook     sunny
# temp         mild
# humidity     high
# windy       False
# play           no
# Name: 7, dtype: object
# 8
# outlook      sunny
# temp          cool
# humidity    normal
# windy        False
# play           yes
# Name: 8, dtype: object
# 9
# outlook      rainy
# temp          mild
# humidity    normal
# windy        False
# play           yes
# Name: 9, dtype: object
# 10
# outlook      sunny
# temp          mild
# humidity    normal
# windy         True
# play           yes
# Name: 10, dtype: object
# 11
# outlook     overcast
# temp            mild
# humidity        high
# windy           True
# play             yes
# Name: 11, dtype: object
# 12
# outlook     overcast
# temp             hot
# humidity      normal
# windy          False
# play             yes
# Name: 12, dtype: object
# 13
# outlook     rainy
# temp         mild
# humidity     high
# windy        True
# play           no
# Name: 13, dtype: object

# %%
for _, row in df_tennis.iterrows(): 
    for col_name, value in row.items():
        print(f"Column Name: {col_name}, Value: {value}")
# Out:
# Column Name: outlook, Value: sunny
# Column Name: temp, Value: hot
# Column Name: humidity, Value: high
# Column Name: windy, Value: False
# Column Name: play, Value: no
# Column Name: outlook, Value: sunny
# Column Name: temp, Value: hot
# Column Name: humidity, Value: high
# Column Name: windy, Value: True
# Column Name: play, Value: no
# Column Name: outlook, Value: overcast
# Column Name: temp, Value: hot
# Column Name: humidity, Value: high
# Column Name: windy, Value: False
# Column Name: play, Value: yes
# Column Name: outlook, Value: rainy
# Column Name: temp, Value: mild
# Column Name: humidity, Value: high
# Column Name: windy, Value: False
# Column Name: play, Value: yes
# Column Name: outlook, Value: rainy
# Column Name: temp, Value: cool
# Column Name: humidity, Value: normal
# Column Name: windy, Value: False
# Column Name: play, Value: yes
# Column Name: outlook, Value: rainy
# Column Name: temp, Value: cool
# Column Name: humidity, Value: normal
# Column Name: windy, Value: True
# Column Name: play, Value: no
# Column Name: outlook, Value: overcast
# Column Name: temp, Value: cool
# Column Name: humidity, Value: normal
# Column Name: windy, Value: True
# Column Name: play, Value: yes
# Column Name: outlook, Value: sunny
# Column Name: temp, Value: mild
# Column Name: humidity, Value: high
# Column Name: windy, Value: False
# Column Name: play, Value: no
# Column Name: outlook, Value: sunny
# Column Name: temp, Value: cool
# Column Name: humidity, Value: normal
# Column Name: windy, Value: False
# Column Name: play, Value: yes
# Column Name: outlook, Value: rainy
# Column Name: temp, Value: mild
# Column Name: humidity, Value: normal
# Column Name: windy, Value: False
# Column Name: play, Value: yes
# Column Name: outlook, Value: sunny
# Column Name: temp, Value: mild
# Column Name: humidity, Value: normal
# Column Name: windy, Value: True
# Column Name: play, Value: yes
# Column Name: outlook, Value: overcast
# Column Name: temp, Value: mild
# Column Name: humidity, Value: high
# Column Name: windy, Value: True
# Column Name: play, Value: yes
# Column Name: outlook, Value: overcast
# Column Name: temp, Value: hot
# Column Name: humidity, Value: normal
# Column Name: windy, Value: False
# Column Name: play, Value: yes
# Column Name: outlook, Value: rainy
# Column Name: temp, Value: mild
# Column Name: humidity, Value: high
# Column Name: windy, Value: True
# Column Name: play, Value: no

# %%
def predict(test_data):
    
    """
        
        Parameters
        ----------
        test_data : dataframe for testing
            pandas df 
        
            
        Returns
        -------
       numpy array for labels returned 
       
    """
    
    """
    Pseudocode: 
    
    1. Check if there is a trained tree. 
    
    2. If there is a trained tree, 
        i) check if all the feature columns are in the test data 
    
    3.  
    
    
    NOTE: For test purpose, assume that the input is one tuple
    """
    
    # 1. Check if there is a trained tree.
    if is_trained == False: 
        
        print("Error: The tree is not trained.")
        return -1 
    
    test_attribute_names = test_data.columns 
    
    print('test_attribute_names : ', list(test_attribute_names) ) 
    
    
    # 2. 
    
    self.list_attribute_names()
    
    
    if test_attributes_names != self.attributes: 
        print("Error: test data has different attributes ", test_attributes_names)
        return -1 
    
    
    """
    self.tree has the tree propagation in list format 
    self.attribute has the list of recorded attributes from training 
    """
    
    test_data = [self.attributes]
    
    
    result = [] # return this as a numpy array/pandas series 
    
        
    
    # iterate across each tuple in test_data and get the value for each column name 
    
    

    def predict_2(test_data):
    
        if not is_trained:
            print("Error: The tree is not trained.")
            return -1 

        # Check if all feature columns are present in test data
        test_attribute_names = test_data.columns 
        
        if not set(test_attribute_names) == set(self.attributes):
            
            print("Error: test data has different attributes ", test_attribute_names)
            return -1 

        # Iterate over each tuple in test_data
        for _, row in test_data.iterrows():
            
            # Create a dictionary with column names as keys and corresponding row values as values
            #test_instance = {col: row[col] for col in self.attributes}

            # Predict the label using the decision tree
            #predicted_label = predict_label(test_instance, self.tree)
            #result.append(predicted_label)
            print('_ : ', _, ', row : ', row)
        #sys.exit(0)
        # Return the predicted labels as a numpy array or pandas series
        
        return np.array(result)

# %%
X_test = df_tennis.drop(columns=['play', 'temp'])

# %%
#predict_3(X_test)

# %%
                

attributes = ['windy', 'humidity', 'outlook']

leaf_nodes = [{'outlook-overcast': 'yes'},
 {'windy-False': 'yes'},
 {'windy-True': 'no'},
 {'humidity-high': 'no'},
 {'humidity-normal': 'yes'}]

tree = [['windy', 'outlook-rainy<-windy->False', 'outlook-rainy<-windy->True'],
 ['humidity',
  'outlook-sunny<-humidity->high',
  'outlook-sunny<-humidity->normal'],
 ['outlook', 'outlook->overcast', 'outlook->rainy', 'outlook->sunny']]
                
                
                
                
tuple_1 = [('outlook', 'sunny'), ('temp', 'hot'), ('humidity', 'high'), ('windy', 'False'), ('play', 'no')]


#leaf_node = {'outlook-overcast': 'yes'}

# Extract key and value separately
#key, value = next(iter(leaf_node.items()))

#print("Key:", key)
#print("Value:", value)



def is_leaf_node(node, leaf_nodes):
    """
    INPUT 
    ------
        node is a string 'attribute-value'
        leaf_nodes is the list of dictionary 
        
        
    RETURN
    ------
    """
    
    #node_key, node_value = node.split('-') 
    
    print('------ is_leaf_node method -----')
    
    for leaf in leaf_nodes:
        
        print('-----')
        print('node to be checked : ', node)
        print('leaf : ', leaf )
        
        leaf_key, leaf_value = next(iter(leaf.items()))
        
        print('leaf_key : ', leaf_key)
        print('leaf_value : ', leaf_value)
        
        if node in leaf:
              
            return True, leaf[node]

    return False, None


        
def predict_tuple(tuple_): 
    
    """
    
    INPUT is a list of (attribute, value) tuples 
    
    -Sample input : [('outlook', 'sunny'), ('temp', 'hot'), ('humidity', 'high'), ('windy', 'False'), ('play', 'no')]


    attributes = ['windy', 'humidity', 'outlook']

    leaf_nodes = [{'outlook-overcast': 'yes'},
     {'windy-False': 'yes'},
     {'windy-True': 'no'},
     {'humidity-high': 'no'},
     {'humidity-normal': 'yes'}]

    tree_ = [['windy', 'outlook-rainy<-windy->False', 'outlook-rainy<-windy->True'],
     
     ['humidity',
      'outlook-sunny<-humidity->high',
      'outlook-sunny<-humidity->normal'],
     
     ['outlook', 'outlook->overcast', 'outlook->rainy', 'outlook->sunny']]


    RETURNS 
    --------
        the label according to the trained tree 

    """
    
    prev_nodes_ = [] 
       
    print('root in tree : ', tree[-1][0])
    
    for attr_val in reversed(tree) : 
        
        """
            Inside the tree. tree[0][0] is the root. 
        """
        
        print('--- reversed tree propagation : ', attr_val)     
        print('--- prev_nodes_ : ', prev_nodes_)
        # check if attr_val[0] is in one of the tuples , if it is present, store it in a variable named attr
        tree_0 = attr_val[0]
        
               
        # in the tuple_ list, get the value for the corresponding value for the respective tree_attr
        
        for _ in tuple_: 
            """
                _ denotes a single entry in the tuple 
            """
                
            if _[0] == tree_0 : 
                
                #test_val = _[1]
                
                print('---------')
                
                print('tree_0 : ', tree_0)
                print('_[0] : ', _[0])
                
                print('=========')
                
                """
                 -Keep checking in test_attr. 
                 -Now, iterate across each attr_val list  
                """
            
                for node_val in attr_val[1: ]: 
                    print('\t\t node val : ', node_val)
                    
                    
                    # take the value for that attribute 
                    value_  = node_val.split('->')[1]
                    print('value from .split : ', value_)
                    print("\t\t_[1] :" , _[1])
                    
                    #print('\t\t_[1] :', _[1])
                    
                    """
                    after split, check value is the second entry of tuple _ 
                    """
                                     
                    
                    if _[1] == value_ :
                        
                        print('\t\t\t-------------in the base case------------------')
                        if len(prev_nodes_) == 0:      
                            print('\t\t\t _[1] and value_ are the same')
                            print('\t\t\t _[1] : ', _[1], ', value_ : ', value_)
                            print('\t\t\t _[0] : ', _[0] )

                            prev_nodes_.append( tree_0 +'-' +_[1] ) 

                            print('\t\t\t prev_node : ', prev_nodes_)

                            """
                            Now check if the tuple-entry is a leaf node 

                            """


                            leaf_node_ , label_ = is_leaf_node( _[0]+'-'+_[1], leaf_nodes)

                            print( "\t\t\tleaf_node_ : ", leaf_node_ , ' label_ : ', label_)


                            if leaf_node_ : 
                                print('\t\t\tlabel for this tuple : ', label_)
                                return label_ 


                            #if len(prev_nodes_ ) != 0: 
                            #    print('\t\t\tthere is an entry is prev node')
                            #    continue
                        
                        else: # after the root is discovered and onwards 
                            print('\t\t\t------------in the induction case------------')
                            
                            print('\t\t\t _[1] and value_ are the same')
                            print('\t\t\t _[1] : ', _[1], ', value_ : ', value_)
                            print('\t\t\t _[0] : ', _[0] )
                            
                            
                            prev_node_ = prev_nodes_[-1]
                            
                            print('\t\t\t prev_node_ : ', prev_node_)
                            print('\t\t\t node_val : ', node_val)
                            
                            
                            
                            
                            if prev_node_ in node_val:
                                print('\t\t\t-------------------prev_node_ in node_val')
                                
                                # split on '<-'
                                pv_, next_node_ = node_val.split('<-')
                                del pv_
                                
                                print('\t\t\t-------------------next_node : ', next_node_)
                                
                                # split next_node 
                                
                                attr_, val_ = next_node_.split('->')
                                
                                print('\t\t\t-------------------attr_ : ', attr_)
                                print('\t\t\t-------------------val_ in tree node: ', val_)
                                print('\t\t\t-------------------value_ in tuple: ', value_)
                            
                                prev_nodes_.append(node_val)
                                
                                leaf_node_ , label_ = is_leaf_node( _[0]+'-'+_[1], leaf_nodes)

                                print( "\t\t\tleaf_node_ : ", leaf_node_ , ' label_ : ', label_)


                                if leaf_node_ : 
                                    print('\t\t\tlabel for this tuple : ', label_)
                                    return label_ 
                                    print('\t\t\t------------end of induction case------------')
                                print('\t\t\t------------end of induction case------------')

                                
                            
                                
                                
                                """
                                value_ : 
                                val_ : 
                                """
                                # check if this attr_ val_ pair is in the tuple 
                            
                            
                        print('\t\t\t-------------------------------')
                #sys.exit(0)
        print('---- prev_nodes_ : ', prev_nodes_)                
        print('end of function')                
                        
                    
                    #if(test_val)
            #sys.exit(0)

# %%
#predict_3(df_tennis)

# %%
predict_tuple(tuple_1)
# Out:
# root in tree :  outlook
# --- reversed tree propagation :  ['outlook', 'outlook->overcast', 'outlook->rainy', 'outlook->sunny']
# --- prev_nodes_ :  []
# ---------
# tree_0 :  outlook
# _[0] :  outlook
# =========
# 		 node val :  outlook->overcast
# value from .split :  overcast
# 		_[1] : sunny
# 		 node val :  outlook->rainy
# value from .split :  rainy
# 		_[1] : sunny
# 		 node val :  outlook->sunny
# value from .split :  sunny
# 		_[1] : sunny
# 			-------------in the base case------------------
# 			 _[1] and value_ are the same
# 			 _[1] :  sunny , value_ :  sunny
# 			 _[0] :  outlook
# 			 prev_node :  ['outlook-sunny']
# ------ is_leaf_node method -----
# -----
# node to be checked :  outlook-sunny
# leaf :  {'outlook-overcast': 'yes'}
# leaf_key :  outlook-overcast
# leaf_value :  yes
# -----
# node to be checked :  outlook-sunny
# leaf :  {'windy-False': 'yes'}
# leaf_key :  windy-False
# leaf_value :  yes
# -----
# node to be checked :  outlook-sunny
# leaf :  {'windy-True': 'no'}
# leaf_key :  windy-True
# leaf_value :  no
# -----
# node to be checked :  outlook-sunny
# leaf :  {'humidity-high': 'no'}
# leaf_key :  humidity-high
# leaf_value :  no
# -----
# node to be checked :  outlook-sunny
# leaf :  {'humidity-normal': 'yes'}
# leaf_key :  humidity-normal
# leaf_value :  yes
# 			leaf_node_ :  False  label_ :  None
# 			-------------------------------
# ---- prev_nodes_ :  ['outlook-sunny']
# end of function
# --- reversed tree propagation :  ['humidity', 'outlook-sunny<-humidity->high', 'outlook-sunny<-humidity->normal']
# --- prev_nodes_ :  ['outlook-sunny']
# ---------
# tree_0 :  humidity
# _[0] :  humidity
# =========
# 		 node val :  outlook-sunny<-humidity->high
# value from .split :  high
# 		_[1] : high
# 			-------------in the base case------------------
# 			------------in the induction case------------
# 			 _[1] and value_ are the same
# 			 _[1] :  high , value_ :  high
# 			 _[0] :  humidity
# 			 prev_node_ :  outlook-sunny
# 			 node_val :  outlook-sunny<-humidity->high
# 			-------------------prev_node_ in node_val
# 			-------------------next_node :  humidity->high
# 			-------------------attr_ :  humidity
# 			-------------------val_ in tree node:  high
# 			-------------------value_ in tuple:  high
# ------ is_leaf_node method -----
# -----
# node to be checked :  humidity-high
# leaf :  {'outlook-overcast': 'yes'}
# leaf_key :  outlook-overcast
# leaf_value :  yes
# -----
# node to be checked :  humidity-high
# leaf :  {'windy-False': 'yes'}
# leaf_key :  windy-False
# leaf_value :  yes
# -----
# node to be checked :  humidity-high
# leaf :  {'windy-True': 'no'}
# leaf_key :  windy-True
# leaf_value :  no
# -----
# node to be checked :  humidity-high
# leaf :  {'humidity-high': 'no'}
# leaf_key :  humidity-high
# leaf_value :  no
# 			leaf_node_ :  True  label_ :  no
# 			label for this tuple :  no
# 'no'

# %%
node_val = 'outlook->overcast'
value = node_val.split('->')[1]
print(value)  # Output: 'overcast'
# Out:
# overcast

# %%
df_tennis
# Out:
#      outlook  temp humidity  windy play
# 0      sunny   hot     high  False   no
# 1      sunny   hot     high   True   no
# 2   overcast   hot     high  False  yes
# 3      rainy  mild     high  False  yes
# 4      rainy  cool   normal  False  yes
# 5      rainy  cool   normal   True   no
# 6   overcast  cool   normal   True  yes
# 7      sunny  mild     high  False   no
# 8      sunny  cool   normal  False  yes
# 9      rainy  mild   normal  False  yes
# 10     sunny  mild   normal   True  yes
# 11  overcast  mild     high   True  yes
# 12  overcast   hot   normal  False  yes
# 13     rainy  mild     high   True   no

# %%
tuple_1
# Out:
# [('outlook', 'sunny'),
#  ('temp', 'hot'),
#  ('humidity', 'high'),
#  ('windy', 'False'),
#  ('play', 'no')]

# %%
#predict_3(X_test)

# %%
tuple_2 = [('outlook', 'overcast'), ('humidity', 'normal'), ('windy', 'True')]

# %%
predict_tuple(tuple_2)
# Out:
# root in tree :  outlook
# --- reversed tree propagation :  ['outlook', 'outlook->overcast', 'outlook->rainy', 'outlook->sunny']
# --- prev_nodes_ :  []
# ---------
# tree_0 :  outlook
# _[0] :  outlook
# =========
# 		 node val :  outlook->overcast
# value from .split :  overcast
# 		_[1] : overcast
# 			-------------in the base case------------------
# 			 _[1] and value_ are the same
# 			 _[1] :  overcast , value_ :  overcast
# 			 _[0] :  outlook
# 			 prev_node :  ['outlook-overcast']
# ------ is_leaf_node method -----
# -----
# node to be checked :  outlook-overcast
# leaf :  {'outlook-overcast': 'yes'}
# leaf_key :  outlook-overcast
# leaf_value :  yes
# 			leaf_node_ :  True  label_ :  yes
# 			label for this tuple :  yes
# 'yes'

# %%
leaf_nodes = [{'outlook-overcast': 'yes'},
 {'windy-False': 'yes'},
 {'windy-True': 'no'},
 {'humidity-high': 'no'},
 {'humidity-normal': 'yes'}]

# %%
leaf_nodes[0]
# Out:
# {'outlook-overcast': 'yes'}

# %%
prev_node_ =  'outlook-sunny'
node_val_ =  'outlook-sunny<-humidity->high'

if prev_node_ in node_val_ : 
    print('blah!')
# Out:
# blah!

# %%
tuple_3 = [('outlook', 'rainy'), ('humidity', 'high'), ('windy', 'True')]
predict_tuple(tuple_3)
# Out:
# root in tree :  outlook
# --- reversed tree propagation :  ['outlook', 'outlook->overcast', 'outlook->rainy', 'outlook->sunny']
# --- prev_nodes_ :  []
# ---------
# tree_0 :  outlook
# _[0] :  outlook
# =========
# 		 node val :  outlook->overcast
# value from .split :  overcast
# 		_[1] : rainy
# 		 node val :  outlook->rainy
# value from .split :  rainy
# 		_[1] : rainy
# 			-------------in the base case------------------
# 			 _[1] and value_ are the same
# 			 _[1] :  rainy , value_ :  rainy
# 			 _[0] :  outlook
# 			 prev_node :  ['outlook-rainy']
# ------ is_leaf_node method -----
# -----
# node to be checked :  outlook-rainy
# leaf :  {'outlook-overcast': 'yes'}
# leaf_key :  outlook-overcast
# leaf_value :  yes
# -----
# node to be checked :  outlook-rainy
# leaf :  {'windy-False': 'yes'}
# leaf_key :  windy-False
# leaf_value :  yes
# -----
# node to be checked :  outlook-rainy
# leaf :  {'windy-True': 'no'}
# leaf_key :  windy-True
# leaf_value :  no
# -----
# node to be checked :  outlook-rainy
# leaf :  {'humidity-high': 'no'}
# leaf_key :  humidity-high
# leaf_value :  no
# -----
# node to be checked :  outlook-rainy
# leaf :  {'humidity-normal': 'yes'}
# leaf_key :  humidity-normal
# leaf_value :  yes
# 			leaf_node_ :  False  label_ :  None
# 			-------------------------------
# 		 node val :  outlook->sunny
# value from .split :  sunny
# 		_[1] : rainy
# ---- prev_nodes_ :  ['outlook-rainy']
# end of function
# --- reversed tree propagation :  ['humidity', 'outlook-sunny<-humidity->high', 'outlook-sunny<-humidity->normal']
# --- prev_nodes_ :  ['outlook-rainy']
# ---------
# tree_0 :  humidity
# _[0] :  humidity
# =========
# 		 node val :  outlook-sunny<-humidity->high
# value from .split :  high
# 		_[1] : high
# 			-------------in the base case------------------
# 			------------in the induction case------------
# 			 _[1] and value_ are the same
# 			 _[1] :  high , value_ :  high
# 			 _[0] :  humidity
# 			 prev_node_ :  outlook-rainy
# 			 node_val :  outlook-sunny<-humidity->high
# 			-------------------------------
# 		 node val :  outlook-sunny<-humidity->normal
# value from .split :  normal
# 		_[1] : high
# ---- prev_nodes_ :  ['outlook-rainy']
# end of function
# --- reversed tree propagation :  ['windy', 'outlook-rainy<-windy->False', 'outlook-rainy<-windy->True']
# --- prev_nodes_ :  ['outlook-rainy']
# ---------
# tree_0 :  windy
# _[0] :  windy
# =========
# 		 node val :  outlook-rainy<-windy->False
# value from .split :  False
# 		_[1] : True
# 		 node val :  outlook-rainy<-windy->True
# value from .split :  True
# 		_[1] : True
# 			-------------in the base case------------------
# 			------------in the induction case------------
# 			 _[1] and value_ are the same
# 			 _[1] :  True , value_ :  True
# 			 _[0] :  windy
# 			 prev_node_ :  outlook-rainy
# 			 node_val :  outlook-rainy<-windy->True
# 			-------------------prev_node_ in node_val
# 			-------------------next_node :  windy->True
# 			-------------------attr_ :  windy
# 			-------------------val_ in tree node:  True
# 			-------------------value_ in tuple:  True
# ------ is_leaf_node method -----
# -----
# node to be checked :  windy-True
# leaf :  {'outlook-overcast': 'yes'}
# leaf_key :  outlook-overcast
# leaf_value :  yes
# -----
# node to be checked :  windy-True
# leaf :  {'windy-False': 'yes'}
# leaf_key :  windy-False
# leaf_value :  yes
# -----
# node to be checked :  windy-True
# leaf :  {'windy-True': 'no'}
# leaf_key :  windy-True
# leaf_value :  no
# 			leaf_node_ :  True  label_ :  no
# 			label for this tuple :  no
# 'no'

# %%
predict_tuple( [('outlook', 'sunny'), ('humidity', 'normal'), ('windy', 'False')] )
# Out:
# root in tree :  outlook
# --- reversed tree propagation :  ['outlook', 'outlook->overcast', 'outlook->rainy', 'outlook->sunny']
# --- prev_nodes_ :  []
# ---------
# tree_0 :  outlook
# _[0] :  outlook
# =========
# 		 node val :  outlook->overcast
# value from .split :  overcast
# 		_[1] : sunny
# 		 node val :  outlook->rainy
# value from .split :  rainy
# 		_[1] : sunny
# 		 node val :  outlook->sunny
# value from .split :  sunny
# 		_[1] : sunny
# 			-------------in the base case------------------
# 			 _[1] and value_ are the same
# 			 _[1] :  sunny , value_ :  sunny
# 			 _[0] :  outlook
# 			 prev_node :  ['outlook-sunny']
# ------ is_leaf_node method -----
# -----
# node to be checked :  outlook-sunny
# leaf :  {'outlook-overcast': 'yes'}
# leaf_key :  outlook-overcast
# leaf_value :  yes
# -----
# node to be checked :  outlook-sunny
# leaf :  {'windy-False': 'yes'}
# leaf_key :  windy-False
# leaf_value :  yes
# -----
# node to be checked :  outlook-sunny
# leaf :  {'windy-True': 'no'}
# leaf_key :  windy-True
# leaf_value :  no
# -----
# node to be checked :  outlook-sunny
# leaf :  {'humidity-high': 'no'}
# leaf_key :  humidity-high
# leaf_value :  no
# -----
# node to be checked :  outlook-sunny
# leaf :  {'humidity-normal': 'yes'}
# leaf_key :  humidity-normal
# leaf_value :  yes
# 			leaf_node_ :  False  label_ :  None
# 			-------------------------------
# ---- prev_nodes_ :  ['outlook-sunny']
# end of function
# --- reversed tree propagation :  ['humidity', 'outlook-sunny<-humidity->high', 'outlook-sunny<-humidity->normal']
# --- prev_nodes_ :  ['outlook-sunny']
# ---------
# tree_0 :  humidity
# _[0] :  humidity
# =========
# 		 node val :  outlook-sunny<-humidity->high
# value from .split :  high
# 		_[1] : normal
# 		 node val :  outlook-sunny<-humidity->normal
# value from .split :  normal
# 		_[1] : normal
# 			-------------in the base case------------------
# 			------------in the induction case------------
# 			 _[1] and value_ are the same
# 			 _[1] :  normal , value_ :  normal
# 			 _[0] :  humidity
# 			 prev_node_ :  outlook-sunny
# 			 node_val :  outlook-sunny<-humidity->normal
# 			-------------------prev_node_ in node_val
# 			-------------------next_node :  humidity->normal
# 			-------------------attr_ :  humidity
# 			-------------------val_ in tree node:  normal
# 			-------------------value_ in tuple:  normal
# ------ is_leaf_node method -----
# -----
# node to be checked :  humidity-normal
# leaf :  {'outlook-overcast': 'yes'}
# leaf_key :  outlook-overcast
# leaf_value :  yes
# -----
# node to be checked :  humidity-normal
# leaf :  {'windy-False': 'yes'}
# leaf_key :  windy-False
# leaf_value :  yes
# -----
# node to be checked :  humidity-normal
# leaf :  {'windy-True': 'no'}
# leaf_key :  windy-True
# leaf_value :  no
# -----
# node to be checked :  humidity-normal
# leaf :  {'humidity-high': 'no'}
# leaf_key :  humidity-high
# leaf_value :  no
# -----
# node to be checked :  humidity-normal
# leaf :  {'humidity-normal': 'yes'}
# leaf_key :  humidity-normal
# leaf_value :  yes
# 			leaf_node_ :  True  label_ :  yes
# 			label for this tuple :  yes
# 'yes'

# %%
def predict(test_data): 
    
    X_pred = []
    
    # Iterate over each tuple in test_data 
    for index, row in test_data.iterrows(): 
                
        tuple_ = []
        
        #print('index : ', index )
        #print('row :\n', row)
        #print('\n')
        for col_name, value in row.items():
            
            #print(f"\t\tColumn Name: {col_name}, Value: {value}")
            
            
            
            tuple_.append( (col_name, value) )
            
            #results.append(  predict_tuple( (col_name, value) )   )
            
            #results.append( predict_tuple(tuple_) ) 
         
        
        #print('data as as list of row, col tuple')
        print(tuple_)
        
        X_pred.append( predict_tuple(tuple_) ) 
        
        #print('*** x_pred = ', x_pred)
    return np.array( X_pred ) 
        
        
        #results.append( X_pred )
        
        
        #return np.array(results)

# %%
r_ = predict(X_test)
# Out:
# [('outlook', 'sunny'), ('humidity', 'high'), ('windy', 'False')]
# root in tree :  outlook
# --- reversed tree propagation :  ['outlook', 'outlook->overcast', 'outlook->rainy', 'outlook->sunny']
# --- prev_nodes_ :  []
# ---------
# tree_0 :  outlook
# _[0] :  outlook
# =========
# 		 node val :  outlook->overcast
# value from .split :  overcast
# 		_[1] : sunny
# 		 node val :  outlook->rainy
# value from .split :  rainy
# 		_[1] : sunny
# 		 node val :  outlook->sunny
# value from .split :  sunny
# 		_[1] : sunny
# 			-------------in the base case------------------
# 			 _[1] and value_ are the same
# 			 _[1] :  sunny , value_ :  sunny
# 			 _[0] :  outlook
# 			 prev_node :  ['outlook-sunny']
# ------ is_leaf_node method -----
# -----
# node to be checked :  outlook-sunny
# leaf :  {'outlook-overcast': 'yes'}
# leaf_key :  outlook-overcast
# leaf_value :  yes
# -----
# node to be checked :  outlook-sunny
# leaf :  {'windy-False': 'yes'}
# leaf_key :  windy-False
# leaf_value :  yes
# -----
# node to be checked :  outlook-sunny
# leaf :  {'windy-True': 'no'}
# leaf_key :  windy-True
# leaf_value :  no
# -----
# node to be checked :  outlook-sunny
# leaf :  {'humidity-high': 'no'}
# leaf_key :  humidity-high
# leaf_value :  no
# -----
# node to be checked :  outlook-sunny
# leaf :  {'humidity-normal': 'yes'}
# leaf_key :  humidity-normal
# leaf_value :  yes
# 			leaf_node_ :  False  label_ :  None
# 			-------------------------------
# ---- prev_nodes_ :  ['outlook-sunny']
# end of function
# --- reversed tree propagation :  ['humidity', 'outlook-sunny<-humidity->high', 'outlook-sunny<-humidity->normal']
# --- prev_nodes_ :  ['outlook-sunny']
# ---------
# tree_0 :  humidity
# _[0] :  humidity
# =========
# 		 node val :  outlook-sunny<-humidity->high
# value from .split :  high
# 		_[1] : high
# 			-------------in the base case------------------
# 			------------in the induction case------------
# 			 _[1] and value_ are the same
# 			 _[1] :  high , value_ :  high
# 			 _[0] :  humidity
# 			 prev_node_ :  outlook-sunny
# 			 node_val :  outlook-sunny<-humidity->high
# 			-------------------prev_node_ in node_val
# 			-------------------next_node :  humidity->high
# 			-------------------attr_ :  humidity
# 			-------------------val_ in tree node:  high
# 			-------------------value_ in tuple:  high
# ------ is_leaf_node method -----
# -----
# node to be checked :  humidity-high
# leaf :  {'outlook-overcast': 'yes'}
# leaf_key :  outlook-overcast
# leaf_value :  yes
# -----
# node to be checked :  humidity-high
# leaf :  {'windy-False': 'yes'}
# leaf_key :  windy-False
# leaf_value :  yes
# -----
# node to be checked :  humidity-high
# leaf :  {'windy-True': 'no'}
# leaf_key :  windy-True
# leaf_value :  no
# -----
# node to be checked :  humidity-high
# leaf :  {'humidity-high': 'no'}
# leaf_key :  humidity-high
# leaf_value :  no
# 			leaf_node_ :  True  label_ :  no
# 			label for this tuple :  no
# [('outlook', 'sunny'), ('humidity', 'high'), ('windy', 'True')]
# root in tree :  outlook
# --- reversed tree propagation :  ['outlook', 'outlook->overcast', 'outlook->rainy', 'outlook->sunny']
# --- prev_nodes_ :  []
# ---------
# tree_0 :  outlook
# _[0] :  outlook
# =========
# 		 node val :  outlook->overcast
# value from .split :  overcast
# 		_[1] : sunny
# 		 node val :  outlook->rainy
# value from .split :  rainy
# 		_[1] : sunny
# 		 node val :  outlook->sunny
# value from .split :  sunny
# 		_[1] : sunny
# 			-------------in the base case------------------
# 			 _[1] and value_ are the same
# 			 _[1] :  sunny , value_ :  sunny
# 			 _[0] :  outlook
# 			 prev_node :  ['outlook-sunny']
# ------ is_leaf_node method -----
# -----
# node to be checked :  outlook-sunny
# leaf :  {'outlook-overcast': 'yes'}
# leaf_key :  outlook-overcast
# leaf_value :  yes
# -----
# node to be checked :  outlook-sunny
# leaf :  {'windy-False': 'yes'}
# leaf_key :  windy-False
# leaf_value :  yes
# -----
# node to be checked :  outlook-sunny
# leaf :  {'windy-True': 'no'}
# leaf_key :  windy-True
# leaf_value :  no
# -----
# node to be checked :  outlook-sunny
# leaf :  {'humidity-high': 'no'}
# leaf_key :  humidity-high
# leaf_value :  no
# -----
# node to be checked :  outlook-sunny
# leaf :  {'humidity-normal': 'yes'}
# leaf_key :  humidity-normal
# leaf_value :  yes
# 			leaf_node_ :  False  label_ :  None
# 			-------------------------------
# ---- prev_nodes_ :  ['outlook-sunny']
# end of function
# --- reversed tree propagation :  ['humidity', 'outlook-sunny<-humidity->high', 'outlook-sunny<-humidity->normal']
# --- prev_nodes_ :  ['outlook-sunny']
# ---------
# tree_0 :  humidity
# _[0] :  humidity
# =========
# 		 node val :  outlook-sunny<-humidity->high
# value from .split :  high
# 		_[1] : high
# 			-------------in the base case------------------
# 			------------in the induction case------------
# 			 _[1] and value_ are the same
# 			 _[1] :  high , value_ :  high
# 			 _[0] :  humidity
# 			 prev_node_ :  outlook-sunny
# 			 node_val :  outlook-sunny<-humidity->high
# 			-------------------prev_node_ in node_val
# 			-------------------next_node :  humidity->high
# 			-------------------attr_ :  humidity
# 			-------------------val_ in tree node:  high
# 			-------------------value_ in tuple:  high
# ------ is_leaf_node method -----
# -----
# node to be checked :  humidity-high
# leaf :  {'outlook-overcast': 'yes'}
# leaf_key :  outlook-overcast
# leaf_value :  yes
# -----
# node to be checked :  humidity-high
# leaf :  {'windy-False': 'yes'}
# leaf_key :  windy-False
# leaf_value :  yes
# -----
# node to be checked :  humidity-high
# leaf :  {'windy-True': 'no'}
# leaf_key :  windy-True
# leaf_value :  no
# -----
# node to be checked :  humidity-high
# leaf :  {'humidity-high': 'no'}
# leaf_key :  humidity-high
# leaf_value :  no
# 			leaf_node_ :  True  label_ :  no
# 			label for this tuple :  no
# [('outlook', 'overcast'), ('humidity', 'high'), ('windy', 'False')]
# root in tree :  outlook
# --- reversed tree propagation :  ['outlook', 'outlook->overcast', 'outlook->rainy', 'outlook->sunny']
# --- prev_nodes_ :  []
# ---------
# tree_0 :  outlook
# _[0] :  outlook
# =========
# 		 node val :  outlook->overcast
# value from .split :  overcast
# 		_[1] : overcast
# 			-------------in the base case------------------
# 			 _[1] and value_ are the same
# 			 _[1] :  overcast , value_ :  overcast
# 			 _[0] :  outlook
# 			 prev_node :  ['outlook-overcast']
# ------ is_leaf_node method -----
# -----
# node to be checked :  outlook-overcast
# leaf :  {'outlook-overcast': 'yes'}
# leaf_key :  outlook-overcast
# leaf_value :  yes
# 			leaf_node_ :  True  label_ :  yes
# 			label for this tuple :  yes
# [('outlook', 'rainy'), ('humidity', 'high'), ('windy', 'False')]
# root in tree :  outlook
# --- reversed tree propagation :  ['outlook', 'outlook->overcast', 'outlook->rainy', 'outlook->sunny']
# --- prev_nodes_ :  []
# ---------
# tree_0 :  outlook
# _[0] :  outlook
# =========
# 		 node val :  outlook->overcast
# value from .split :  overcast
# 		_[1] : rainy
# 		 node val :  outlook->rainy
# value from .split :  rainy
# 		_[1] : rainy
# 			-------------in the base case------------------
# 			 _[1] and value_ are the same
# 			 _[1] :  rainy , value_ :  rainy
# 			 _[0] :  outlook
# 			 prev_node :  ['outlook-rainy']
# ------ is_leaf_node method -----
# -----
# node to be checked :  outlook-rainy
# leaf :  {'outlook-overcast': 'yes'}
# leaf_key :  outlook-overcast
# leaf_value :  yes
# -----
# node to be checked :  outlook-rainy
# leaf :  {'windy-False': 'yes'}
# leaf_key :  windy-False
# leaf_value :  yes
# -----
# node to be checked :  outlook-rainy
# leaf :  {'windy-True': 'no'}
# leaf_key :  windy-True
# leaf_value :  no
# -----
# node to be checked :  outlook-rainy
# leaf :  {'humidity-high': 'no'}
# leaf_key :  humidity-high
# leaf_value :  no
# -----
# node to be checked :  outlook-rainy
# leaf :  {'humidity-normal': 'yes'}
# leaf_key :  humidity-normal
# leaf_value :  yes
# 			leaf_node_ :  False  label_ :  None
# 			-------------------------------
# 		 node val :  outlook->sunny
# value from .split :  sunny
# 		_[1] : rainy
# ---- prev_nodes_ :  ['outlook-rainy']
# end of function
# --- reversed tree propagation :  ['humidity', 'outlook-sunny<-humidity->high', 'outlook-sunny<-humidity->normal']
# --- prev_nodes_ :  ['outlook-rainy']
# ---------
# tree_0 :  humidity
# _[0] :  humidity
# =========
# 		 node val :  outlook-sunny<-humidity->high
# value from .split :  high
# 		_[1] : high
# 			-------------in the base case------------------
# 			------------in the induction case------------
# 			 _[1] and value_ are the same
# 			 _[1] :  high , value_ :  high
# 			 _[0] :  humidity
# 			 prev_node_ :  outlook-rainy
# 			 node_val :  outlook-sunny<-humidity->high
# 			-------------------------------
# 		 node val :  outlook-sunny<-humidity->normal
# value from .split :  normal
# 		_[1] : high
# ---- prev_nodes_ :  ['outlook-rainy']
# end of function
# --- reversed tree propagation :  ['windy', 'outlook-rainy<-windy->False', 'outlook-rainy<-windy->True']
# --- prev_nodes_ :  ['outlook-rainy']
# ---------
# tree_0 :  windy
# _[0] :  windy
# =========
# 		 node val :  outlook-rainy<-windy->False
# value from .split :  False
# 		_[1] : False
# 			-------------in the base case------------------
# 			------------in the induction case------------
# 			 _[1] and value_ are the same
# 			 _[1] :  False , value_ :  False
# 			 _[0] :  windy
# 			 prev_node_ :  outlook-rainy
# 			 node_val :  outlook-rainy<-windy->False
# 			-------------------prev_node_ in node_val
# 			-------------------next_node :  windy->False
# 			-------------------attr_ :  windy
# 			-------------------val_ in tree node:  False
# 			-------------------value_ in tuple:  False
# ------ is_leaf_node method -----
# -----
# node to be checked :  windy-False
# leaf :  {'outlook-overcast': 'yes'}
# leaf_key :  outlook-overcast
# leaf_value :  yes
# -----
# node to be checked :  windy-False
# leaf :  {'windy-False': 'yes'}
# leaf_key :  windy-False
# leaf_value :  yes
# 			leaf_node_ :  True  label_ :  yes
# 			label for this tuple :  yes
# [('outlook', 'rainy'), ('humidity', 'normal'), ('windy', 'False')]
# root in tree :  outlook
# --- reversed tree propagation :  ['outlook', 'outlook->overcast', 'outlook->rainy', 'outlook->sunny']
# --- prev_nodes_ :  []
# ---------
# tree_0 :  outlook
# _[0] :  outlook
# =========
# 		 node val :  outlook->overcast
# value from .split :  overcast
# 		_[1] : rainy
# 		 node val :  outlook->rainy
# value from .split :  rainy
# 		_[1] : rainy
# 			-------------in the base case------------------
# 			 _[1] and value_ are the same
# 			 _[1] :  rainy , value_ :  rainy
# 			 _[0] :  outlook
# 			 prev_node :  ['outlook-rainy']
# ------ is_leaf_node method -----
# -----
# node to be checked :  outlook-rainy
# leaf :  {'outlook-overcast': 'yes'}
# leaf_key :  outlook-overcast
# leaf_value :  yes
# -----
# node to be checked :  outlook-rainy
# leaf :  {'windy-False': 'yes'}
# leaf_key :  windy-False
# leaf_value :  yes
# -----
# node to be checked :  outlook-rainy
# leaf :  {'windy-True': 'no'}
# leaf_key :  windy-True
# leaf_value :  no
# -----
# node to be checked :  outlook-rainy
# leaf :  {'humidity-high': 'no'}
# leaf_key :  humidity-high
# leaf_value :  no
# -----
# node to be checked :  outlook-rainy
# leaf :  {'humidity-normal': 'yes'}
# leaf_key :  humidity-normal
# leaf_value :  yes
# 			leaf_node_ :  False  label_ :  None
# 			-------------------------------
# 		 node val :  outlook->sunny
# value from .split :  sunny
# 		_[1] : rainy
# ---- prev_nodes_ :  ['outlook-rainy']
# end of function
# --- reversed tree propagation :  ['humidity', 'outlook-sunny<-humidity->high', 'outlook-sunny<-humidity->normal']
# --- prev_nodes_ :  ['outlook-rainy']
# ---------
# tree_0 :  humidity
# _[0] :  humidity
# =========
# 		 node val :  outlook-sunny<-humidity->high
# value from .split :  high
# 		_[1] : normal
# 		 node val :  outlook-sunny<-humidity->normal
# value from .split :  normal
# 		_[1] : normal
# 			-------------in the base case------------------
# 			------------in the induction case------------
# 			 _[1] and value_ are the same
# 			 _[1] :  normal , value_ :  normal
# 			 _[0] :  humidity
# 			 prev_node_ :  outlook-rainy
# 			 node_val :  outlook-sunny<-humidity->normal
# 			-------------------------------
# ---- prev_nodes_ :  ['outlook-rainy']
# end of function
# --- reversed tree propagation :  ['windy', 'outlook-rainy<-windy->False', 'outlook-rainy<-windy->True']
# --- prev_nodes_ :  ['outlook-rainy']
# ---------
# tree_0 :  windy
# _[0] :  windy
# =========
# 		 node val :  outlook-rainy<-windy->False
# value from .split :  False
# 		_[1] : False
# 			-------------in the base case------------------
# 			------------in the induction case------------
# 			 _[1] and value_ are the same
# 			 _[1] :  False , value_ :  False
# 			 _[0] :  windy
# 			 prev_node_ :  outlook-rainy
# 			 node_val :  outlook-rainy<-windy->False
# 			-------------------prev_node_ in node_val
# 			-------------------next_node :  windy->False
# 			-------------------attr_ :  windy
# 			-------------------val_ in tree node:  False
# 			-------------------value_ in tuple:  False
# ------ is_leaf_node method -----
# -----
# node to be checked :  windy-False
# leaf :  {'outlook-overcast': 'yes'}
# leaf_key :  outlook-overcast
# leaf_value :  yes
# -----
# node to be checked :  windy-False
# leaf :  {'windy-False': 'yes'}
# leaf_key :  windy-False
# leaf_value :  yes
# 			leaf_node_ :  True  label_ :  yes
# 			label for this tuple :  yes
# [('outlook', 'rainy'), ('humidity', 'normal'), ('windy', 'True')]
# root in tree :  outlook
# --- reversed tree propagation :  ['outlook', 'outlook->overcast', 'outlook->rainy', 'outlook->sunny']
# --- prev_nodes_ :  []
# ---------
# tree_0 :  outlook
# _[0] :  outlook
# =========
# 		 node val :  outlook->overcast
# value from .split :  overcast
# 		_[1] : rainy
# 		 node val :  outlook->rainy
# value from .split :  rainy
# 		_[1] : rainy
# 			-------------in the base case------------------
# 			 _[1] and value_ are the same
# 			 _[1] :  rainy , value_ :  rainy
# 			 _[0] :  outlook
# 			 prev_node :  ['outlook-rainy']
# ------ is_leaf_node method -----
# -----
# node to be checked :  outlook-rainy
# leaf :  {'outlook-overcast': 'yes'}
# leaf_key :  outlook-overcast
# leaf_value :  yes
# -----
# node to be checked :  outlook-rainy
# leaf :  {'windy-False': 'yes'}
# leaf_key :  windy-False
# leaf_value :  yes
# -----
# node to be checked :  outlook-rainy
# leaf :  {'windy-True': 'no'}
# leaf_key :  windy-True
# leaf_value :  no
# -----
# node to be checked :  outlook-rainy
# leaf :  {'humidity-high': 'no'}
# leaf_key :  humidity-high
# leaf_value :  no
# -----
# node to be checked :  outlook-rainy
# leaf :  {'humidity-normal': 'yes'}
# leaf_key :  humidity-normal
# leaf_value :  yes
# 			leaf_node_ :  False  label_ :  None
# 			-------------------------------
# 		 node val :  outlook->sunny
# value from .split :  sunny
# 		_[1] : rainy
# ---- prev_nodes_ :  ['outlook-rainy']
# end of function
# --- reversed tree propagation :  ['humidity', 'outlook-sunny<-humidity->high', 'outlook-sunny<-humidity->normal']
# --- prev_nodes_ :  ['outlook-rainy']
# ---------
# tree_0 :  humidity
# _[0] :  humidity
# =========
# 		 node val :  outlook-sunny<-humidity->high
# value from .split :  high
# 		_[1] : normal
# 		 node val :  outlook-sunny<-humidity->normal
# value from .split :  normal
# 		_[1] : normal
# 			-------------in the base case------------------
# 			------------in the induction case------------
# 			 _[1] and value_ are the same
# 			 _[1] :  normal , value_ :  normal
# 			 _[0] :  humidity
# 			 prev_node_ :  outlook-rainy
# 			 node_val :  outlook-sunny<-humidity->normal
# 			-------------------------------
# ---- prev_nodes_ :  ['outlook-rainy']
# end of function
# --- reversed tree propagation :  ['windy', 'outlook-rainy<-windy->False', 'outlook-rainy<-windy->True']
# --- prev_nodes_ :  ['outlook-rainy']
# ---------
# tree_0 :  windy
# _[0] :  windy
# =========
# 		 node val :  outlook-rainy<-windy->False
# value from .split :  False
# 		_[1] : True
# 		 node val :  outlook-rainy<-windy->True
# value from .split :  True
# 		_[1] : True
# 			-------------in the base case------------------
# 			------------in the induction case------------
# 			 _[1] and value_ are the same
# 			 _[1] :  True , value_ :  True
# 			 _[0] :  windy
# 			 prev_node_ :  outlook-rainy
# 			 node_val :  outlook-rainy<-windy->True
# 			-------------------prev_node_ in node_val
# 			-------------------next_node :  windy->True
# 			-------------------attr_ :  windy
# 			-------------------val_ in tree node:  True
# 			-------------------value_ in tuple:  True
# ------ is_leaf_node method -----
# -----
# node to be checked :  windy-True
# leaf :  {'outlook-overcast': 'yes'}
# leaf_key :  outlook-overcast
# leaf_value :  yes
# -----
# node to be checked :  windy-True
# leaf :  {'windy-False': 'yes'}
# leaf_key :  windy-False
# leaf_value :  yes
# -----
# node to be checked :  windy-True
# leaf :  {'windy-True': 'no'}
# leaf_key :  windy-True
# leaf_value :  no
# 			leaf_node_ :  True  label_ :  no
# 			label for this tuple :  no
# [('outlook', 'overcast'), ('humidity', 'normal'), ('windy', 'True')]
# root in tree :  outlook
# --- reversed tree propagation :  ['outlook', 'outlook->overcast', 'outlook->rainy', 'outlook->sunny']
# --- prev_nodes_ :  []
# ---------
# tree_0 :  outlook
# _[0] :  outlook
# =========
# 		 node val :  outlook->overcast
# value from .split :  overcast
# 		_[1] : overcast
# 			-------------in the base case------------------
# 			 _[1] and value_ are the same
# 			 _[1] :  overcast , value_ :  overcast
# 			 _[0] :  outlook
# 			 prev_node :  ['outlook-overcast']
# ------ is_leaf_node method -----
# -----
# node to be checked :  outlook-overcast
# leaf :  {'outlook-overcast': 'yes'}
# leaf_key :  outlook-overcast
# leaf_value :  yes
# 			leaf_node_ :  True  label_ :  yes
# 			label for this tuple :  yes
# [('outlook', 'sunny'), ('humidity', 'high'), ('windy', 'False')]
# root in tree :  outlook
# --- reversed tree propagation :  ['outlook', 'outlook->overcast', 'outlook->rainy', 'outlook->sunny']
# --- prev_nodes_ :  []
# ---------
# tree_0 :  outlook
# _[0] :  outlook
# =========
# 		 node val :  outlook->overcast
# value from .split :  overcast
# 		_[1] : sunny
# 		 node val :  outlook->rainy
# value from .split :  rainy
# 		_[1] : sunny
# 		 node val :  outlook->sunny
# value from .split :  sunny
# 		_[1] : sunny
# 			-------------in the base case------------------
# 			 _[1] and value_ are the same
# 			 _[1] :  sunny , value_ :  sunny
# 			 _[0] :  outlook
# 			 prev_node :  ['outlook-sunny']
# ------ is_leaf_node method -----
# -----
# node to be checked :  outlook-sunny
# leaf :  {'outlook-overcast': 'yes'}
# leaf_key :  outlook-overcast
# leaf_value :  yes
# -----
# node to be checked :  outlook-sunny
# leaf :  {'windy-False': 'yes'}
# leaf_key :  windy-False
# leaf_value :  yes
# -----
# node to be checked :  outlook-sunny
# leaf :  {'windy-True': 'no'}
# leaf_key :  windy-True
# leaf_value :  no
# -----
# node to be checked :  outlook-sunny
# leaf :  {'humidity-high': 'no'}
# leaf_key :  humidity-high
# leaf_value :  no
# -----
# node to be checked :  outlook-sunny
# leaf :  {'humidity-normal': 'yes'}
# leaf_key :  humidity-normal
# leaf_value :  yes
# 			leaf_node_ :  False  label_ :  None
# 			-------------------------------
# ---- prev_nodes_ :  ['outlook-sunny']
# end of function
# --- reversed tree propagation :  ['humidity', 'outlook-sunny<-humidity->high', 'outlook-sunny<-humidity->normal']
# --- prev_nodes_ :  ['outlook-sunny']
# ---------
# tree_0 :  humidity
# _[0] :  humidity
# =========
# 		 node val :  outlook-sunny<-humidity->high
# value from .split :  high
# 		_[1] : high
# 			-------------in the base case------------------
# 			------------in the induction case------------
# 			 _[1] and value_ are the same
# 			 _[1] :  high , value_ :  high
# 			 _[0] :  humidity
# 			 prev_node_ :  outlook-sunny
# 			 node_val :  outlook-sunny<-humidity->high
# 			-------------------prev_node_ in node_val
# 			-------------------next_node :  humidity->high
# 			-------------------attr_ :  humidity
# 			-------------------val_ in tree node:  high
# 			-------------------value_ in tuple:  high
# ------ is_leaf_node method -----
# -----
# node to be checked :  humidity-high
# leaf :  {'outlook-overcast': 'yes'}
# leaf_key :  outlook-overcast
# leaf_value :  yes
# -----
# node to be checked :  humidity-high
# leaf :  {'windy-False': 'yes'}
# leaf_key :  windy-False
# leaf_value :  yes
# -----
# node to be checked :  humidity-high
# leaf :  {'windy-True': 'no'}
# leaf_key :  windy-True
# leaf_value :  no
# -----
# node to be checked :  humidity-high
# leaf :  {'humidity-high': 'no'}
# leaf_key :  humidity-high
# leaf_value :  no
# 			leaf_node_ :  True  label_ :  no
# 			label for this tuple :  no
# [('outlook', 'sunny'), ('humidity', 'normal'), ('windy', 'False')]
# root in tree :  outlook
# --- reversed tree propagation :  ['outlook', 'outlook->overcast', 'outlook->rainy', 'outlook->sunny']
# --- prev_nodes_ :  []
# ---------
# tree_0 :  outlook
# _[0] :  outlook
# =========
# 		 node val :  outlook->overcast
# value from .split :  overcast
# 		_[1] : sunny
# 		 node val :  outlook->rainy
# value from .split :  rainy
# 		_[1] : sunny
# 		 node val :  outlook->sunny
# value from .split :  sunny
# 		_[1] : sunny
# 			-------------in the base case------------------
# 			 _[1] and value_ are the same
# 			 _[1] :  sunny , value_ :  sunny
# 			 _[0] :  outlook
# 			 prev_node :  ['outlook-sunny']
# ------ is_leaf_node method -----
# -----
# node to be checked :  outlook-sunny
# leaf :  {'outlook-overcast': 'yes'}
# leaf_key :  outlook-overcast
# leaf_value :  yes
# -----
# node to be checked :  outlook-sunny
# leaf :  {'windy-False': 'yes'}
# leaf_key :  windy-False
# leaf_value :  yes
# -----
# node to be checked :  outlook-sunny
# leaf :  {'windy-True': 'no'}
# leaf_key :  windy-True
# leaf_value :  no
# -----
# node to be checked :  outlook-sunny
# leaf :  {'humidity-high': 'no'}
# leaf_key :  humidity-high
# leaf_value :  no
# -----
# node to be checked :  outlook-sunny
# leaf :  {'humidity-normal': 'yes'}
# leaf_key :  humidity-normal
# leaf_value :  yes
# 			leaf_node_ :  False  label_ :  None
# 			-------------------------------
# ---- prev_nodes_ :  ['outlook-sunny']
# end of function
# --- reversed tree propagation :  ['humidity', 'outlook-sunny<-humidity->high', 'outlook-sunny<-humidity->normal']
# --- prev_nodes_ :  ['outlook-sunny']
# ---------
# tree_0 :  humidity
# _[0] :  humidity
# =========
# 		 node val :  outlook-sunny<-humidity->high
# value from .split :  high
# 		_[1] : normal
# 		 node val :  outlook-sunny<-humidity->normal
# value from .split :  normal
# 		_[1] : normal
# 			-------------in the base case------------------
# 			------------in the induction case------------
# 			 _[1] and value_ are the same
# 			 _[1] :  normal , value_ :  normal
# 			 _[0] :  humidity
# 			 prev_node_ :  outlook-sunny
# 			 node_val :  outlook-sunny<-humidity->normal
# 			-------------------prev_node_ in node_val
# 			-------------------next_node :  humidity->normal
# 			-------------------attr_ :  humidity
# 			-------------------val_ in tree node:  normal
# 			-------------------value_ in tuple:  normal
# ------ is_leaf_node method -----
# -----
# node to be checked :  humidity-normal
# leaf :  {'outlook-overcast': 'yes'}
# leaf_key :  outlook-overcast
# leaf_value :  yes
# -----
# node to be checked :  humidity-normal
# leaf :  {'windy-False': 'yes'}
# leaf_key :  windy-False
# leaf_value :  yes
# -----
# node to be checked :  humidity-normal
# leaf :  {'windy-True': 'no'}
# leaf_key :  windy-True
# leaf_value :  no
# -----
# node to be checked :  humidity-normal
# leaf :  {'humidity-high': 'no'}
# leaf_key :  humidity-high
# leaf_value :  no
# -----
# node to be checked :  humidity-normal
# leaf :  {'humidity-normal': 'yes'}
# leaf_key :  humidity-normal
# leaf_value :  yes
# 			leaf_node_ :  True  label_ :  yes
# 			label for this tuple :  yes
# [('outlook', 'rainy'), ('humidity', 'normal'), ('windy', 'False')]
# root in tree :  outlook
# --- reversed tree propagation :  ['outlook', 'outlook->overcast', 'outlook->rainy', 'outlook->sunny']
# --- prev_nodes_ :  []
# ---------
# tree_0 :  outlook
# _[0] :  outlook
# =========
# 		 node val :  outlook->overcast
# value from .split :  overcast
# 		_[1] : rainy
# 		 node val :  outlook->rainy
# value from .split :  rainy
# 		_[1] : rainy
# 			-------------in the base case------------------
# 			 _[1] and value_ are the same
# 			 _[1] :  rainy , value_ :  rainy
# 			 _[0] :  outlook
# 			 prev_node :  ['outlook-rainy']
# ------ is_leaf_node method -----
# -----
# node to be checked :  outlook-rainy
# leaf :  {'outlook-overcast': 'yes'}
# leaf_key :  outlook-overcast
# leaf_value :  yes
# -----
# node to be checked :  outlook-rainy
# leaf :  {'windy-False': 'yes'}
# leaf_key :  windy-False
# leaf_value :  yes
# -----
# node to be checked :  outlook-rainy
# leaf :  {'windy-True': 'no'}
# leaf_key :  windy-True
# leaf_value :  no
# -----
# node to be checked :  outlook-rainy
# leaf :  {'humidity-high': 'no'}
# leaf_key :  humidity-high
# leaf_value :  no
# -----
# node to be checked :  outlook-rainy
# leaf :  {'humidity-normal': 'yes'}
# leaf_key :  humidity-normal
# leaf_value :  yes
# 			leaf_node_ :  False  label_ :  None
# 			-------------------------------
# 		 node val :  outlook->sunny
# value from .split :  sunny
# 		_[1] : rainy
# ---- prev_nodes_ :  ['outlook-rainy']
# end of function
# --- reversed tree propagation :  ['humidity', 'outlook-sunny<-humidity->high', 'outlook-sunny<-humidity->normal']
# --- prev_nodes_ :  ['outlook-rainy']
# ---------
# tree_0 :  humidity
# _[0] :  humidity
# =========
# 		 node val :  outlook-sunny<-humidity->high
# value from .split :  high
# 		_[1] : normal
# 		 node val :  outlook-sunny<-humidity->normal
# value from .split :  normal
# 		_[1] : normal
# 			-------------in the base case------------------
# 			------------in the induction case------------
# 			 _[1] and value_ are the same
# 			 _[1] :  normal , value_ :  normal
# 			 _[0] :  humidity
# 			 prev_node_ :  outlook-rainy
# 			 node_val :  outlook-sunny<-humidity->normal
# 			-------------------------------
# ---- prev_nodes_ :  ['outlook-rainy']
# end of function
# --- reversed tree propagation :  ['windy', 'outlook-rainy<-windy->False', 'outlook-rainy<-windy->True']
# --- prev_nodes_ :  ['outlook-rainy']
# ---------
# tree_0 :  windy
# _[0] :  windy
# =========
# 		 node val :  outlook-rainy<-windy->False
# value from .split :  False
# 		_[1] : False
# 			-------------in the base case------------------
# 			------------in the induction case------------
# 			 _[1] and value_ are the same
# 			 _[1] :  False , value_ :  False
# 			 _[0] :  windy
# 			 prev_node_ :  outlook-rainy
# 			 node_val :  outlook-rainy<-windy->False
# 			-------------------prev_node_ in node_val
# 			-------------------next_node :  windy->False
# 			-------------------attr_ :  windy
# 			-------------------val_ in tree node:  False
# 			-------------------value_ in tuple:  False
# ------ is_leaf_node method -----
# -----
# node to be checked :  windy-False
# leaf :  {'outlook-overcast': 'yes'}
# leaf_key :  outlook-overcast
# leaf_value :  yes
# -----
# node to be checked :  windy-False
# leaf :  {'windy-False': 'yes'}
# leaf_key :  windy-False
# leaf_value :  yes
# 			leaf_node_ :  True  label_ :  yes
# 			label for this tuple :  yes
# [('outlook', 'sunny'), ('humidity', 'normal'), ('windy', 'True')]
# root in tree :  outlook
# --- reversed tree propagation :  ['outlook', 'outlook->overcast', 'outlook->rainy', 'outlook->sunny']
# --- prev_nodes_ :  []
# ---------
# tree_0 :  outlook
# _[0] :  outlook
# =========
# 		 node val :  outlook->overcast
# value from .split :  overcast
# 		_[1] : sunny
# 		 node val :  outlook->rainy
# value from .split :  rainy
# 		_[1] : sunny
# 		 node val :  outlook->sunny
# value from .split :  sunny
# 		_[1] : sunny
# 			-------------in the base case------------------
# 			 _[1] and value_ are the same
# 			 _[1] :  sunny , value_ :  sunny
# 			 _[0] :  outlook
# 			 prev_node :  ['outlook-sunny']
# ------ is_leaf_node method -----
# -----
# node to be checked :  outlook-sunny
# leaf :  {'outlook-overcast': 'yes'}
# leaf_key :  outlook-overcast
# leaf_value :  yes
# -----
# node to be checked :  outlook-sunny
# leaf :  {'windy-False': 'yes'}
# leaf_key :  windy-False
# leaf_value :  yes
# -----
# node to be checked :  outlook-sunny
# leaf :  {'windy-True': 'no'}
# leaf_key :  windy-True
# leaf_value :  no
# -----
# node to be checked :  outlook-sunny
# leaf :  {'humidity-high': 'no'}
# leaf_key :  humidity-high
# leaf_value :  no
# -----
# node to be checked :  outlook-sunny
# leaf :  {'humidity-normal': 'yes'}
# leaf_key :  humidity-normal
# leaf_value :  yes
# 			leaf_node_ :  False  label_ :  None
# 			-------------------------------
# ---- prev_nodes_ :  ['outlook-sunny']
# end of function
# --- reversed tree propagation :  ['humidity', 'outlook-sunny<-humidity->high', 'outlook-sunny<-humidity->normal']
# --- prev_nodes_ :  ['outlook-sunny']
# ---------
# tree_0 :  humidity
# _[0] :  humidity
# =========
# 		 node val :  outlook-sunny<-humidity->high
# value from .split :  high
# 		_[1] : normal
# 		 node val :  outlook-sunny<-humidity->normal
# value from .split :  normal
# 		_[1] : normal
# 			-------------in the base case------------------
# 			------------in the induction case------------
# 			 _[1] and value_ are the same
# 			 _[1] :  normal , value_ :  normal
# 			 _[0] :  humidity
# 			 prev_node_ :  outlook-sunny
# 			 node_val :  outlook-sunny<-humidity->normal
# 			-------------------prev_node_ in node_val
# 			-------------------next_node :  humidity->normal
# 			-------------------attr_ :  humidity
# 			-------------------val_ in tree node:  normal
# 			-------------------value_ in tuple:  normal
# ------ is_leaf_node method -----
# -----
# node to be checked :  humidity-normal
# leaf :  {'outlook-overcast': 'yes'}
# leaf_key :  outlook-overcast
# leaf_value :  yes
# -----
# node to be checked :  humidity-normal
# leaf :  {'windy-False': 'yes'}
# leaf_key :  windy-False
# leaf_value :  yes
# -----
# node to be checked :  humidity-normal
# leaf :  {'windy-True': 'no'}
# leaf_key :  windy-True
# leaf_value :  no
# -----
# node to be checked :  humidity-normal
# leaf :  {'humidity-high': 'no'}
# leaf_key :  humidity-high
# leaf_value :  no
# -----
# node to be checked :  humidity-normal
# leaf :  {'humidity-normal': 'yes'}
# leaf_key :  humidity-normal
# leaf_value :  yes
# 			leaf_node_ :  True  label_ :  yes
# 			label for this tuple :  yes
# [('outlook', 'overcast'), ('humidity', 'high'), ('windy', 'True')]
# root in tree :  outlook
# --- reversed tree propagation :  ['outlook', 'outlook->overcast', 'outlook->rainy', 'outlook->sunny']
# --- prev_nodes_ :  []
# ---------
# tree_0 :  outlook
# _[0] :  outlook
# =========
# 		 node val :  outlook->overcast
# value from .split :  overcast
# 		_[1] : overcast
# 			-------------in the base case------------------
# 			 _[1] and value_ are the same
# 			 _[1] :  overcast , value_ :  overcast
# 			 _[0] :  outlook
# 			 prev_node :  ['outlook-overcast']
# ------ is_leaf_node method -----
# -----
# node to be checked :  outlook-overcast
# leaf :  {'outlook-overcast': 'yes'}
# leaf_key :  outlook-overcast
# leaf_value :  yes
# 			leaf_node_ :  True  label_ :  yes
# 			label for this tuple :  yes
# [('outlook', 'overcast'), ('humidity', 'normal'), ('windy', 'False')]
# root in tree :  outlook
# --- reversed tree propagation :  ['outlook', 'outlook->overcast', 'outlook->rainy', 'outlook->sunny']
# --- prev_nodes_ :  []
# ---------
# tree_0 :  outlook
# _[0] :  outlook
# =========
# 		 node val :  outlook->overcast
# value from .split :  overcast
# 		_[1] : overcast
# 			-------------in the base case------------------
# 			 _[1] and value_ are the same
# 			 _[1] :  overcast , value_ :  overcast
# 			 _[0] :  outlook
# 			 prev_node :  ['outlook-overcast']
# ------ is_leaf_node method -----
# -----
# node to be checked :  outlook-overcast
# leaf :  {'outlook-overcast': 'yes'}
# leaf_key :  outlook-overcast
# leaf_value :  yes
# 			leaf_node_ :  True  label_ :  yes
# 			label for this tuple :  yes
# [('outlook', 'rainy'), ('humidity', 'high'), ('windy', 'True')]
# root in tree :  outlook
# --- reversed tree propagation :  ['outlook', 'outlook->overcast', 'outlook->rainy', 'outlook->sunny']
# --- prev_nodes_ :  []
# ---------
# tree_0 :  outlook
# _[0] :  outlook
# =========
# 		 node val :  outlook->overcast
# value from .split :  overcast
# 		_[1] : rainy
# 		 node val :  outlook->rainy
# value from .split :  rainy
# 		_[1] : rainy
# 			-------------in the base case------------------
# 			 _[1] and value_ are the same
# 			 _[1] :  rainy , value_ :  rainy
# 			 _[0] :  outlook
# 			 prev_node :  ['outlook-rainy']
# ------ is_leaf_node method -----
# -----
# node to be checked :  outlook-rainy
# leaf :  {'outlook-overcast': 'yes'}
# leaf_key :  outlook-overcast
# leaf_value :  yes
# -----
# node to be checked :  outlook-rainy
# leaf :  {'windy-False': 'yes'}
# leaf_key :  windy-False
# leaf_value :  yes
# -----
# node to be checked :  outlook-rainy
# leaf :  {'windy-True': 'no'}
# leaf_key :  windy-True
# leaf_value :  no
# -----
# node to be checked :  outlook-rainy
# leaf :  {'humidity-high': 'no'}
# leaf_key :  humidity-high
# leaf_value :  no
# -----
# node to be checked :  outlook-rainy
# leaf :  {'humidity-normal': 'yes'}
# leaf_key :  humidity-normal
# leaf_value :  yes
# 			leaf_node_ :  False  label_ :  None
# 			-------------------------------
# 		 node val :  outlook->sunny
# value from .split :  sunny
# 		_[1] : rainy
# ---- prev_nodes_ :  ['outlook-rainy']
# end of function
# --- reversed tree propagation :  ['humidity', 'outlook-sunny<-humidity->high', 'outlook-sunny<-humidity->normal']
# --- prev_nodes_ :  ['outlook-rainy']
# ---------
# tree_0 :  humidity
# _[0] :  humidity
# =========
# 		 node val :  outlook-sunny<-humidity->high
# value from .split :  high
# 		_[1] : high
# 			-------------in the base case------------------
# 			------------in the induction case------------
# 			 _[1] and value_ are the same
# 			 _[1] :  high , value_ :  high
# 			 _[0] :  humidity
# 			 prev_node_ :  outlook-rainy
# 			 node_val :  outlook-sunny<-humidity->high
# 			-------------------------------
# 		 node val :  outlook-sunny<-humidity->normal
# value from .split :  normal
# 		_[1] : high
# ---- prev_nodes_ :  ['outlook-rainy']
# end of function
# --- reversed tree propagation :  ['windy', 'outlook-rainy<-windy->False', 'outlook-rainy<-windy->True']
# --- prev_nodes_ :  ['outlook-rainy']
# ---------
# tree_0 :  windy
# _[0] :  windy
# =========
# 		 node val :  outlook-rainy<-windy->False
# value from .split :  False
# 		_[1] : True
# 		 node val :  outlook-rainy<-windy->True
# value from .split :  True
# 		_[1] : True
# 			-------------in the base case------------------
# 			------------in the induction case------------
# 			 _[1] and value_ are the same
# 			 _[1] :  True , value_ :  True
# 			 _[0] :  windy
# 			 prev_node_ :  outlook-rainy
# 			 node_val :  outlook-rainy<-windy->True
# 			-------------------prev_node_ in node_val
# 			-------------------next_node :  windy->True
# 			-------------------attr_ :  windy
# 			-------------------val_ in tree node:  True
# 			-------------------value_ in tuple:  True
# ------ is_leaf_node method -----
# -----
# node to be checked :  windy-True
# leaf :  {'outlook-overcast': 'yes'}
# leaf_key :  outlook-overcast
# leaf_value :  yes
# -----
# node to be checked :  windy-True
# leaf :  {'windy-False': 'yes'}
# leaf_key :  windy-False
# leaf_value :  yes
# -----
# node to be checked :  windy-True
# leaf :  {'windy-True': 'no'}
# leaf_key :  windy-True
# leaf_value :  no
# 			leaf_node_ :  True  label_ :  no
# 			label for this tuple :  no

# %%
len(r_)
# Out:
# 14

# %%
X_test
# Out:
#      outlook humidity  windy
# 0      sunny     high  False
# 1      sunny     high   True
# 2   overcast     high  False
# 3      rainy     high  False
# 4      rainy   normal  False
# 5      rainy   normal   True
# 6   overcast   normal   True
# 7      sunny     high  False
# 8      sunny   normal  False
# 9      rainy   normal  False
# 10     sunny   normal   True
# 11  overcast     high   True
# 12  overcast   normal  False
# 13     rainy     high   True

# %%
r_
# Out:
# array(['no', 'no', 'yes', 'yes', 'yes', 'no', 'yes', 'no', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'no'], dtype='<U3')

# %%
r_.shape
# Out:
# (14,)

# %%
f_exp = np.array([44, 24, 29, 3]) / 100 * 189
f_obs = np.array([43, 52, 54, 40])

# %%
from scipy.stats import chisquare
chisquare(f_obs=f_obs, f_exp=f_exp)
# Out:
# Power_divergenceResult(statistic=228.23515947653874, pvalue=3.3295585338846486e-49)

# %%
import pandas as pd
import numpy as np

from scipy.stats import chi2_contingency

# Sample data with categorical features and a binary target variable
data = {
    'feature1': np.random.choice(['A', 'B', 'C'], size=100),
    'feature2': np.random.choice(['Yes', 'No'], size=100),
    'target': np.random.choice(['Positive', 'Negative'], size=100, p=[0.6, 0.4])  # Control class distribution
}

df = pd.DataFrame(data)

print(df.head())
print(df.shape)


print(np.unique(df['feature1'], return_counts=True))
print(np.unique(df['feature2'], return_counts=True))
print(np.unique(df['target'], return_counts=True))
# Out:
#   feature1 feature2    target
# 0        C       No  Positive
# 1        A       No  Positive
# 2        C       No  Positive
# 3        B      Yes  Negative
# 4        C       No  Negative
# (100, 3)
# (array(['A', 'B', 'C'], dtype=object), array([39, 27, 34]))
# (array(['No', 'Yes'], dtype=object), array([46, 54]))
# (array(['Negative', 'Positive'], dtype=object), array([38, 62]))

# %%
#from scipy.stats import chi2_contingency

# %%
# Function to test chi-squared for a given feature and target
def test_chi_squared(data, feature, target, alpha=0.05):  # Replace 'alpha' with your significance level
    
    contingency_table = pd.crosstab(data[feature], data[target]) # (feature_values_as_rows, target_value_as_column)
    
    print('======== INPUT ========')
    
    print('---contingency_table---')
    display(contingency_table)
    print('-------------')
    
    chi2, pval, degrees_of_freedom, expected_table = chi2_contingency(contingency_table)

    print('======== OUTPUT ========')
    #print('---expected table---')
    #display(expected_table)
    #print('-------------')

    print('---chi2---')
    display(chi2)
    print('-------------')

    print('---pval---')
    display(pval)
    print('-------------')
    
    
    print('---degrees_of_freedom---')
    display(degrees_of_freedom)
    print('-------------')
    
    print('---expected_table---')
    display(expected_table)
    print('-------------')

    
    
    
    if pval < alpha:
        print(f"Feature '{feature}' has a significant association with the target variable (p-value: {pval:.4f}).")
    else:
        print(f"Feature '{feature}' does not have a significant association with the target variable (p-value: {pval:.4f}).")

# Test chi-squared for each feature
for feature in ['feature1', 'feature2']:
    test_chi_squared(df, feature, 'target')
# Out:
# ======== INPUT ========
# ---contingency_table---
# target    Negative  Positive
# feature1
# A               16        23
# B                9        18
# C               13        21
# -------------
# ======== OUTPUT ========
# ---chi2---
# 0.4019134100028938
# -------------
# ---pval---
# 0.8179478438379819
# -------------
# ---degrees_of_freedom---
# 2
# -------------
# ---expected_table---
# array([[14.82, 24.18],
#        [10.26, 16.74],
#        [12.92, 21.08]])
# -------------
# Feature 'feature1' does not have a significant association with the target variable (p-value: 0.8179).
# ======== INPUT ========
# ---contingency_table---
# target    Negative  Positive
# feature2
# No              15        31
# Yes             23        31
# -------------
# ======== OUTPUT ========
# ---chi2---
# 0.6698900125489037
# -------------
# ---pval---
# 0.41308995628779466
# -------------
# ---degrees_of_freedom---
# 1
# -------------
# ---expected_table---
# array([[17.48, 28.52],
#        [20.52, 33.48]])
# -------------
# Feature 'feature2' does not have a significant association with the target variable (p-value: 0.4131).

# %%
import numpy as np
from scipy.stats import chi2_contingency

# Sample data
data = pd.DataFrame({
    'feature1': np.random.choice(['A', 'B', 'C'], size=100),
    'feature2': np.random.choice(['Yes', 'No'], size=100),
    'target': np.random.choice(['Positive', 'Negative'], size=100, p=[0.6, 0.4])
})

# Analyze association between a feature (e.g., 'feature1') and the target variable
chosen_feature = 'feature1'

# Create contingency table (observed data)
contingency_table = pd.crosstab(data[chosen_feature], data['target'])

# Expected table (replace with your calculations if needed)
# For simplicity, assuming equal expected distribution here (modify as needed)
expected_table = np.array([[30, 20], [30, 20], [30, 20]])  # Adjust values based on your assumptions

# %%
contingency_table
# Out:
# target    Negative  Positive
# feature1
# A               16        16
# B                9        21
# C               14        24

# %%
expected_table
# Out:
# array([[30, 20],
#        [30, 20],
#        [30, 20]])

# %%
chi2, pval, dof, expected_freqs = chi2_contingency(contingency_table, expected_table)

# Set your desired significance level (alpha)
alpha = 0.05

if pval < alpha:
    print(f"Feature '{chosen_feature}' has a significant association with the target variable (p-value: {pval:.4f}).")
else:
    print(f"Feature '{chosen_feature}' does not have a significant association with the target variable (p-value: {pval:.4f}).")
# Out:
# Feature 'feature1' does not have a significant association with the target variable (p-value: 0.2562).

# %%
def chi_squared_test(actual_table, confidence_level=0.90): 
    """
    INPUT 
    ---- 
    
    contingency_table
    ---
        pandas df - The contigency_table is has value count from examples_vi - the actual one 
    
    
    RETURNS
    ----
    
    Boolean variable : True or False 
    
    """
    
    chi2, pval, dof, expected_freqs = chi2_contingency(actual_table)
    
    alpha = 1 - confidence_level

    if pval < alpha:
        print(f"Feature '{chosen_feature}' has a significant association with the target variable (p-value: {pval:.4f}).")
        return True
    
    
    else:
        print(f"Feature '{chosen_feature}' does not have a significant association with the target variable (p-value: {pval:.4f}).")
        return False

# %%
chi_squared_test(contingency_table, confidence_level=0.90)
# Out:
# Feature 'feature1' does not have a significant association with the target variable (p-value: 0.2562).
# False
